# %%
import dill
import pandas as pd
import numpy as np
from langchain.llms import Cohere, OpenAI, GooglePalm, Anthropic
from langchain.prompts import PromptTemplate
from langchain.output_parsers import PydanticOutputParser
from langchain.pydantic_v1 import BaseModel, Field, validator
from typing import List
from tqdm.auto import tqdm
from pypdf import PdfReader

from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())

# %% [markdown]
# # Load Data
#
# Load data gathered in an excel spreadsheet

# %%
df = pd.read_excel(
    '../data/CSC869 Term Project Dataset.xlsx', 
    sheet_name='Course Descriptions', 
    skiprows=3, 
    names=['School', 'MATH226 eqv', 'MATH226 mult eqv', 'MATH226 alt eqv', 'MATH226 alt mult eqv', 'CSC230 eqv', 'CSC230 alt eqv', 'CSC256 eqv', 'CSC256 multipleEqv'],
    index_col=None
)
df = df.dropna(how='all').set_index("School")

# %%
math226_desc = df.iloc[0,0]
csc230_desc = df.iloc[0,4]
csc256_desc = df.iloc[0,6]
print(math226_desc, "\n\n")
print(csc230_desc, "\n\n")
print(csc256_desc)
# Out:
# MATH 226 - Calculus I
# 4 Units
#
# Graphs. Differentiation: theory, techniques, and applications. Integration: Fundamental Theorem of Calculus and applications. Transcendental functions.
#
#
# CSC 230 - Discrete Mathematical Structures for Computer Science
# 3 Units
#
# Review of set algebra, relations and functions, permutations, propositional logic, proof techniques, introduction to graph theory, and infinite sets, and their applications to computer science.
#
#
# CSC 256 - Machine Structures
# 3 Units
#
# Digital logic circuits, data representation, assembly language programming, subroutine linkage, machine language encoding, interrupt and exception handling, memory system concepts, and CPU organization and performance.

# %%
df
# Out:
#                                                                                           MATH226 eqv  \
# School
# SFSU                                                MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# Berkeley City College                               MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# California Polytechnic State University, Humboldt   MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# California Polytechnic State University, Pomona     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# California Polytechnic State University, San Lu...  MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# ...                                                                                               ...
# Solano Community College                            MATH020:\n\n4.0 Units\nPrint\nDescription:\n\n...
# Sonoma State University                             MATH 161 - Differential and Integral Calculus ...
# Ventura College                                     MATH V21A Calculus with Analytic Geometry I 5 ...
# West Valley College                                 MATH 003A: Calculus and Analytical Geometry\nC...
# Yuba College                                        MATH-1A 4 UNITS\nSingle Variable Calculus I - ...
#
#                                                                                      MATH226 mult eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  MATH 142 - Calculus II\n4 units\nGE Area B1\nP...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                       MATH226 alt eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 141 - Calculus I \n4 Units \nPrerequisite...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                  MATH226 alt mult eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 142 - Calculus II \n4 units\nPrerequisite...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                            CSC230 eqv  \
# School
# SFSU                                                CSC 230 - Discrete Mathematical Structures for...
# Berkeley City College                                  MATH 11 - Discrete Mathematics\n4 units\n\nN/A
# California Polytechnic State University, Humboldt   MATH 253 - Discrete Mathematics\n3 Units, 3 Le...
# California Polytechnic State University, Pomona     CS 1300 - Discrete Structures\n4 Units\nPrereq...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS021:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                     MATH V52 Discrete Structures 3 Units\nSame-As:...
# West Valley College                                 MATH 019: Discrete Mathematics\nCourse Descrip...
# Yuba College                                        COMSC-15 3 UNITS\nDiscrete Structures for Comp...
#
#                                                                                        CSC230 alt eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                     CS V17 Discrete Structures 3 Units\nSame-As: M...
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                            CSC256 eqv  \
# School
# SFSU                                                CSC 256 - Machine Structures\n3 Units\n\nDigit...
# Berkeley City College                               CIS 20: Microcomputer Assembly Language\n4 Uni...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     CS 2640 - Computer Organization and Assembly P...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        COMSC-2 3 UNITS\nComputer Assembly Language\nT...
#
#                                                    CSC256 multipleEqv
# School
# SFSU                                                              NaN
# Berkeley City College                                             NaN
# California Polytechnic State University, Humboldt                 NaN
# California Polytechnic State University, Pomona                   NaN
# California Polytechnic State University, San Lu...                NaN
# ...                                                               ...
# Solano Community College                                          NaN
# Sonoma State University                                           NaN
# Ventura College                                                   NaN
# West Valley College                                               NaN
# Yuba College                                                      NaN
#
# [63 rows x 8 columns]

# %% [markdown]
# # Extract Topics
#
# Exploration and testing of topic (and general data) extraction.

# %% [markdown]
# ## Initialize LLM

# %%
# llm_cohere = ChatCohere(temperature=0)
# cgpt = OpenAI(model_name="text-davinci-003", temperature=0)
# cohere = Cohere(model="command", temperature=0)
palm = GooglePalm(model_name="models/text-bison-001", temperature=0)

# %% [markdown]
# ## Create Course Class for Output Parsing

# %%
class Course(BaseModel):
    name: str = Field(description="name of the course")
    discipline: str = Field(description="academic discipline of the course")
    # add college name?
    topics: List[str] = Field(description="list of topics that the course covers")

course_parser = PydanticOutputParser(pydantic_object=Course)

# %% [markdown]
# ## Create Prompt from Template

# %% [markdown]
# ### Prompt Template for Prompt Generation

# %%
# Prompt Template to extract only course information
# course_query = """\
# For the course description, extract the course information.\n\
# {format_instructions}\n\n\
# This is the course description to be analyzed:\n```{course_desc}```\n
# """

course_prompt_template = """
For the course description, extract the course information.  Categorize the \
academic discipline that the course belongs to.\n
{format_instructions}\n\n
This is the course description to be analyzed:\n{course_desc}\n
"""

course_desc = df.iloc[2,4]

# %%
course_desc
# Out:
# 'MATH 253 - Discrete Mathematics\n3 Units, 3 Lecture Hours\nPrerequisites: MATH 101T (C), or MATH 102 and CS 111\n\nSets, functions, relations, algorithms, induction, recursion, combinatorics, graphs, trees, and propositional logic.'

# %%
course_prompt = PromptTemplate(
    template=course_prompt_template,
    input_variables=["course_desc"],
    partial_variables={"format_instructions": course_parser.get_format_instructions()}
)

# %%
_input = course_prompt.format_prompt(course_desc=course_desc)

# %%
print(_input.to_string())
# Out:
# For the course description, extract the course information.  Categorize the academic discipline that the course belongs to.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"name": {"title": "Name", "description": "name of the course", "type": "string"}, "discipline": {"title": "Discipline", "description": "academic discipline of the course", "type": "string"}, "topics": {"title": "Topics", "description": "list of topics that the course covers", "type": "array", "items": {"type": "string"}}}, "required": ["name", "discipline", "topics"]}
# ```
#
#
# This is the course description to be analyzed:
# MATH 253 - Discrete Mathematics
# 3 Units, 3 Lecture Hours
# Prerequisites: MATH 101T (C), or MATH 102 and CS 111
#
# Sets, functions, relations, algorithms, induction, recursion, combinatorics, graphs, trees, and propositional logic.

# %%
# output_cohere = cohere(_input.to_string())
# output_cgpt = cgpt(_input.to_string())

# %%
course_output_palm = palm(_input.to_string())

# %%
course_output_palm
# Out:
# '```\n{\n  "name": "MATH 253 - Discrete Mathematics",\n  "discipline": "Mathematics",\n  "topics": ["Sets", "Functions", "Relations", "Algorithms", "Induction", "Recursion", "Combinatorics", "Graphs", "Trees", "Propositional Logic"]\n}\n```'

# %%
course_data_palm = course_parser.parse(course_output_palm)

# %%
course_data_palm.discipline
# Out:
# 'Mathematics'

# %% [markdown]
# # Process Entire DataFrame
#
# Here, I take the exploration that was completed above to develop functions that
# allow for our entire dataframe to be processed.

# %%
from tqdm.auto import tqdm

def process_course(course_desc: str):
    if course_desc is np.NaN:
        return np.NaN
    _input = prompt.format_prompt(course_desc=course_desc)
    result = palm(_input.to_string())
    return result

def process_all_courses(df: pd.DataFrame):
    for col in tqdm(df.columns, desc="Total Progress", position=0):
        df[f"{col} data"] = list(map(process_course, tqdm(df.loc[:, col], desc=f"{col}", position=1)))
    return df

# %%
toy_df = df.iloc[2:5].copy()
toy_df
# Out:
#                                                                                           MATH226 eqv  \
# School
# California Polytechnic State University, Humboldt   MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# California Polytechnic State University, Pomona     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# California Polytechnic State University, San Lu...  MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
#
#                                                                                      MATH226 mult eqv  \
# School
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  MATH 142 - Calculus II\n4 units\nGE Area B1\nP...
#
#                                                                                       MATH226 alt eqv  \
# School
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 141 - Calculus I \n4 Units \nPrerequisite...
#
#                                                                                  MATH226 alt mult eqv  \
# School
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 142 - Calculus II \n4 units\nPrerequisite...
#
#                                                                                            CSC230 eqv  \
# School
# California Polytechnic State University, Humboldt   MATH 253 - Discrete Mathematics\n3 Units, 3 Le...
# California Polytechnic State University, Pomona     CS 1300 - Discrete Structures\n4 Units\nPrereq...
# California Polytechnic State University, San Lu...                                                NaN
#
#                                                    CSC230 alt eqv  \
# School
# California Polytechnic State University, Humboldt             NaN
# California Polytechnic State University, Pomona               NaN
# California Polytechnic State University, San Lu...            NaN
#
#                                                                                            CSC256 eqv  \
# School
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     CS 2640 - Computer Organization and Assembly P...
# California Polytechnic State University, San Lu...                                                NaN
#
#                                                    CSC256 multipleEqv
# School
# California Polytechnic State University, Humboldt                 NaN
# California Polytechnic State University, Pomona                   NaN
# California Polytechnic State University, San Lu...                NaN

# %%
# toy_df2 = process_all_courses(toy_df)
# toy_df2

# %%
# toy_df2.iloc[0,8]

# %%
# df2 = process_all_courses(df)

# %%
# df2

# %%
# with open('../data/course_desc_and_data.pkl', 'wb') as f:
#     dill.dump(df2, f)

with open('../data/course_desc_and_data.pkl', 'rb') as f:
    df2 = dill.load(f)

# %%
df2
# Out:
#                                                                                           MATH226 eqv  \
# School
# SFSU                                                MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# Berkeley City College                               MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# California Polytechnic State University, Humboldt   MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# California Polytechnic State University, Pomona     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# California Polytechnic State University, San Lu...  MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# ...                                                                                               ...
# Solano Community College                            MATH020:\n\n4.0 Units\nPrint\nDescription:\n\n...
# Sonoma State University                             MATH 161 - Differential and Integral Calculus ...
# Ventura College                                     MATH V21A Calculus with Analytic Geometry I 5 ...
# West Valley College                                 MATH 003A: Calculus and Analytical Geometry\nC...
# Yuba College                                        MATH-1A 4 UNITS\nSingle Variable Calculus I - ...
#
#                                                                                      MATH226 mult eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  MATH 142 - Calculus II\n4 units\nGE Area B1\nP...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                       MATH226 alt eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 141 - Calculus I \n4 Units \nPrerequisite...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                  MATH226 alt mult eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 142 - Calculus II \n4 units\nPrerequisite...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                            CSC230 eqv  \
# School
# SFSU                                                CSC 230 - Discrete Mathematical Structures for...
# Berkeley City College                                  MATH 11 - Discrete Mathematics\n4 units\n\nN/A
# California Polytechnic State University, Humboldt   MATH 253 - Discrete Mathematics\n3 Units, 3 Le...
# California Polytechnic State University, Pomona     CS 1300 - Discrete Structures\n4 Units\nPrereq...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS021:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                     MATH V52 Discrete Structures 3 Units\nSame-As:...
# West Valley College                                 MATH 019: Discrete Mathematics\nCourse Descrip...
# Yuba College                                        COMSC-15 3 UNITS\nDiscrete Structures for Comp...
#
#                                                                                        CSC230 alt eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                     CS V17 Discrete Structures 3 Units\nSame-As: M...
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                            CSC256 eqv  \
# School
# SFSU                                                CSC 256 - Machine Structures\n3 Units\n\nDigit...
# Berkeley City College                               CIS 20: Microcomputer Assembly Language\n4 Uni...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     CS 2640 - Computer Organization and Assembly P...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        COMSC-2 3 UNITS\nComputer Assembly Language\nT...
#
#                                                    CSC256 multipleEqv  \
# School
# SFSU                                                              NaN
# Berkeley City College                                             NaN
# California Polytechnic State University, Humboldt                 NaN
# California Polytechnic State University, Pomona                   NaN
# California Polytechnic State University, San Lu...                NaN
# ...                                                               ...
# Solano Community College                                          NaN
# Sonoma State University                                           NaN
# Ventura College                                                   NaN
# West Valley College                                               NaN
# Yuba College                                                      NaN
#
#                                                                                      MATH226 eqv data  \
# School
# SFSU                                                {"name": "MATH 226 - Calculus I", "discipline"...
# Berkeley City College                               ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...
# California Polytechnic State University, San Lu...  {"name": "MATH 141 - Calculus I", "discipline"...
# ...                                                                                               ...
# Solano Community College                            {"name": "MATH020", "discipline": "Mathematics...
# Sonoma State University                             ```\n{\n  "name": "MATH 161 - Differential and...
# Ventura College                                     ```\n{\n  "name": "MATH V21A Calculus with Ana...
# West Valley College                                 ```\n{\n  "name": "MATH 003A: Calculus and Ana...
# Yuba College                                        ```\n{\n  "name": "MATH-1A",\n  "discipline": ...
#
#                                                                                 MATH226 mult eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  ```\n{\n  "name": "MATH 142 - Calculus II",\n ...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                  MATH226 alt eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  ```\n{\n  "name": "HNRS 141 - Calculus I",\n  ...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                             MATH226 alt mult eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  ```\n{\n  "name": "HNRS 142 - Calculus II",\n ...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                       CSC230 eqv data  \
# School
# SFSU                                                {"name": "CSC 230 - Discrete Mathematical Stru...
# Berkeley City College                               {"name": "MATH 11 - Discrete Mathematics", "di...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 253 - Discrete Mathema...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 1300 - Discrete Structur...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            ```\n{\n  "name": "CIS021",\n  "discipline": "...
# Sonoma State University                                                                           NaN
# Ventura College                                     ```\n{\n  "name": "MATH V52 Discrete Structure...
# West Valley College                                 ```\n{\n  "name": "MATH 019: Discrete Mathemat...
# Yuba College                                        ```\n{\n  "name": "COMSC-15",\n  "discipline":...
#
#                                                                                   CSC230 alt eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                     ```\n{\n  "name": "CS V17 Discrete Structures"...
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                       CSC256 eqv data  \
# School
# SFSU                                                ```\n{\n  "name": "CSC 256 - Machine Structure...
# Berkeley City College                               ```\n{\n  "name": "CIS 20: Microcomputer Assem...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 2640 - Computer Organiza...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            {"name": "CIS020", "discipline": "Computer Sci...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        ```\n{\n  "name": "Computer Assembly Language"...
#
#                                                    CSC256 multipleEqv data
# School
# SFSU                                                                   NaN
# Berkeley City College                                                  NaN
# California Polytechnic State University, Humboldt                      NaN
# California Polytechnic State University, Pomona                        NaN
# California Polytechnic State University, San Lu...                     NaN
# ...                                                                    ...
# Solano Community College                                               NaN
# Sonoma State University                                                NaN
# Ventura College                                                        NaN
# West Valley College                                                    NaN
# Yuba College                                                           NaN
#
# [63 rows x 16 columns]

# %%
df2.iloc[0,8]
# Out:
# '{"name": "MATH 226 - Calculus I", "discipline": "Mathematics", "topics": ["Calculus", "Differentiation", "Integration", "Transcendental functions"]}'

# %%
course_data_palm = course_parser.parse(df2.iloc[0,8])
course_data_palm
# Out:
# Course(name='MATH 226 - Calculus I', discipline='Mathematics', topics=['Calculus', 'Differentiation', 'Integration', 'Transcendental functions'])

# %%
course_data_palm.topics
# Out:
# list

# %% [markdown]
# # Create Positive and Negative Test Case Dataset

# %% [markdown]
# ## Construct Positive Cases
#
# The set of positive equivalencies were created from course articulation
# agreements with SFSU only.  To expand the set of positive equivalencies, we
# assume that any course from a college that has an articulated course with SFSU
# is also equivalent to any other course from another college that has an
# articulation agreement with SFSU.
#
# By doing this, we increase the number of positive cases from $62$ to $1953$ for each
# course, of which, we have 3 (Calculus I, Discrete Math, and Machine Structures).
# So for each course we have
# $$ C(n,k) = \frac{P(n,k)}{k!} = \frac{n!}{k!(n-k)!} $$
# $$ C(63,2) = \frac{63!}{2(61!)} = \frac{63\cdot 62}{2} = 1953. $$
# Then by applying this to all three cases, we construct $4259$ positive cases
# ($5859$ total positive pairs $- 1600$ unarticulated courses $= 4259$).

# %%
pairs_list = []
count = 0
df_test_cases = df2.iloc[:,[0, 4, 6, 8, 12, 14]]
for i in range(int(len(df_test_cases.columns)/2)):
    for j, desc in enumerate(df_test_cases.iloc[:,i]):
        for k in range(j+1,len(df_test_cases.iloc[:,i])):
            if (type(desc) is str) and (type(df_test_cases.iloc[k,i]) is str):
                pairs_list.append((desc, df_test_cases.iloc[k,i], df_test_cases.iloc[j,i+3], df_test_cases.iloc[k,i+3], 1))
            else:
                count += 1

# %%
len(pairs_list)
# Out:
# 4259

# %% [markdown]
# ##### Sanity Check

# %%
count
# Out:
# 1600

# %%
len(pairs_list)
# Out:
# 4259

# %%
count + len(pairs_list)
# Out:
# 5859

# %%
df_eval = pd.DataFrame(pairs_list, columns=['target_raw', 'source_raw', 'target_topics', 'source_topics', 'label'])
df_eval
# Out:
#                                              target_raw  \
# 0     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 1     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 2     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 3     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 4     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# ...                                                 ...
# 4254  CSCI 0039. Introduction to Computer Architectu...
# 4255  CSCI 0039. Introduction to Computer Architectu...
# 4256  COMP 256 Computer Architecture and Assembly La...
# 4257  COMP 256 Computer Architecture and Assembly La...
# 4258  CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
#
#                                              source_raw  \
# 0     MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# 1     MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# 2     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# 3     MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# 4     MATH 150 - Calculus I\n4 Units\nFour hours lec...
# ...                                                 ...
# 4254  CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# 4255  COMSC-2 3 UNITS\nComputer Assembly Language\nT...
# 4256  CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# 4257  COMSC-2 3 UNITS\nComputer Assembly Language\nT...
# 4258  COMSC-2 3 UNITS\nComputer Assembly Language\nT...
#
#                                           target_topics  \
# 0     {"name": "MATH 226 - Calculus I", "discipline"...
# 1     {"name": "MATH 226 - Calculus I", "discipline"...
# 2     {"name": "MATH 226 - Calculus I", "discipline"...
# 3     {"name": "MATH 226 - Calculus I", "discipline"...
# 4     {"name": "MATH 226 - Calculus I", "discipline"...
# ...                                                 ...
# 4254  ```\n{\n  "name": "CSCI 0039. Introduction to ...
# 4255  ```\n{\n  "name": "CSCI 0039. Introduction to ...
# 4256  ```\n{\n  "name": "COMP 256 Computer Architect...
# 4257  ```\n{\n  "name": "COMP 256 Computer Architect...
# 4258  {"name": "CIS020", "discipline": "Computer Sci...
#
#                                           source_topics  label
# 0     ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...      1
# 1     ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...      1
# 2     ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...      1
# 3     {"name": "MATH 141 - Calculus I", "discipline"...      1
# 4     ```\n{\n  "name": "MATH 150 - Calculus I",\n  ...      1
# ...                                                 ...    ...
# 4254  {"name": "CIS020", "discipline": "Computer Sci...      1
# 4255  ```\n{\n  "name": "Computer Assembly Language"...      1
# 4256  {"name": "CIS020", "discipline": "Computer Sci...      1
# 4257  ```\n{\n  "name": "Computer Assembly Language"...      1
# 4258  ```\n{\n  "name": "Computer Assembly Language"...      1
#
# [4259 rows x 5 columns]

# %%
df_eval.iloc[170]
# Out:
# target_raw       MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# source_raw       MATH 150 Calculus with Analytic Geometry I (5 ...
# target_topics    ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...
# source_topics    ```\n{\n  "name": "MATH 150 Calculus with Anal...
# label                                                            1
# Name: 170, dtype: object

# %% [markdown]
# ## Sample for Negative Cases
#
# This set of negative cases for course articulation is created by sampling
# courses that are definitively not equivalent (e.g. Calculus I and Machine
# Structures).
#
# We want to keep the dataset balanced, so we will sample $4259/3 \approx 1420$
# negative cases from each course type we are assessing.  The way we accomplish
# this is by sampling the target courses and then sampling known negative cases
# for equivalency from one of the other courses.
#
# Example:
# We randomly sample a set of courses from "MATH 226" equivalencies.  Then we match each of
# those courses that we sampled with another random sample from a concatenated
# Series from both "CSC 230" and "CSC 256" equivalencies.

# %%
df2
# Out:
#                                                                                           MATH226 eqv  \
# School
# SFSU                                                MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# Berkeley City College                               MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# California Polytechnic State University, Humboldt   MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# California Polytechnic State University, Pomona     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# California Polytechnic State University, San Lu...  MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# ...                                                                                               ...
# Solano Community College                            MATH020:\n\n4.0 Units\nPrint\nDescription:\n\n...
# Sonoma State University                             MATH 161 - Differential and Integral Calculus ...
# Ventura College                                     MATH V21A Calculus with Analytic Geometry I 5 ...
# West Valley College                                 MATH 003A: Calculus and Analytical Geometry\nC...
# Yuba College                                        MATH-1A 4 UNITS\nSingle Variable Calculus I - ...
#
#                                                                                      MATH226 mult eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  MATH 142 - Calculus II\n4 units\nGE Area B1\nP...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                       MATH226 alt eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 141 - Calculus I \n4 Units \nPrerequisite...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                  MATH226 alt mult eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 142 - Calculus II \n4 units\nPrerequisite...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                            CSC230 eqv  \
# School
# SFSU                                                CSC 230 - Discrete Mathematical Structures for...
# Berkeley City College                                  MATH 11 - Discrete Mathematics\n4 units\n\nN/A
# California Polytechnic State University, Humboldt   MATH 253 - Discrete Mathematics\n3 Units, 3 Le...
# California Polytechnic State University, Pomona     CS 1300 - Discrete Structures\n4 Units\nPrereq...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS021:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                     MATH V52 Discrete Structures 3 Units\nSame-As:...
# West Valley College                                 MATH 019: Discrete Mathematics\nCourse Descrip...
# Yuba College                                        COMSC-15 3 UNITS\nDiscrete Structures for Comp...
#
#                                                                                        CSC230 alt eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                     CS V17 Discrete Structures 3 Units\nSame-As: M...
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                            CSC256 eqv  \
# School
# SFSU                                                CSC 256 - Machine Structures\n3 Units\n\nDigit...
# Berkeley City College                               CIS 20: Microcomputer Assembly Language\n4 Uni...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     CS 2640 - Computer Organization and Assembly P...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        COMSC-2 3 UNITS\nComputer Assembly Language\nT...
#
#                                                    CSC256 multipleEqv  \
# School
# SFSU                                                              NaN
# Berkeley City College                                             NaN
# California Polytechnic State University, Humboldt                 NaN
# California Polytechnic State University, Pomona                   NaN
# California Polytechnic State University, San Lu...                NaN
# ...                                                               ...
# Solano Community College                                          NaN
# Sonoma State University                                           NaN
# Ventura College                                                   NaN
# West Valley College                                               NaN
# Yuba College                                                      NaN
#
#                                                                                      MATH226 eqv data  \
# School
# SFSU                                                {"name": "MATH 226 - Calculus I", "discipline"...
# Berkeley City College                               ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...
# California Polytechnic State University, San Lu...  {"name": "MATH 141 - Calculus I", "discipline"...
# ...                                                                                               ...
# Solano Community College                            {"name": "MATH020", "discipline": "Mathematics...
# Sonoma State University                             ```\n{\n  "name": "MATH 161 - Differential and...
# Ventura College                                     ```\n{\n  "name": "MATH V21A Calculus with Ana...
# West Valley College                                 ```\n{\n  "name": "MATH 003A: Calculus and Ana...
# Yuba College                                        ```\n{\n  "name": "MATH-1A",\n  "discipline": ...
#
#                                                                                 MATH226 mult eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  ```\n{\n  "name": "MATH 142 - Calculus II",\n ...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                  MATH226 alt eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  ```\n{\n  "name": "HNRS 141 - Calculus I",\n  ...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                             MATH226 alt mult eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  ```\n{\n  "name": "HNRS 142 - Calculus II",\n ...
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                       CSC230 eqv data  \
# School
# SFSU                                                {"name": "CSC 230 - Discrete Mathematical Stru...
# Berkeley City College                               {"name": "MATH 11 - Discrete Mathematics", "di...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 253 - Discrete Mathema...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 1300 - Discrete Structur...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            ```\n{\n  "name": "CIS021",\n  "discipline": "...
# Sonoma State University                                                                           NaN
# Ventura College                                     ```\n{\n  "name": "MATH V52 Discrete Structure...
# West Valley College                                 ```\n{\n  "name": "MATH 019: Discrete Mathemat...
# Yuba College                                        ```\n{\n  "name": "COMSC-15",\n  "discipline":...
#
#                                                                                   CSC230 alt eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                                                                          NaN
# Sonoma State University                                                                           NaN
# Ventura College                                     ```\n{\n  "name": "CS V17 Discrete Structures"...
# West Valley College                                                                               NaN
# Yuba College                                                                                      NaN
#
#                                                                                       CSC256 eqv data  \
# School
# SFSU                                                ```\n{\n  "name": "CSC 256 - Machine Structure...
# Berkeley City College                               ```\n{\n  "name": "CIS 20: Microcomputer Assem...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 2640 - Computer Organiza...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            {"name": "CIS020", "discipline": "Computer Sci...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        ```\n{\n  "name": "Computer Assembly Language"...
#
#                                                    CSC256 multipleEqv data
# School
# SFSU                                                                   NaN
# Berkeley City College                                                  NaN
# California Polytechnic State University, Humboldt                      NaN
# California Polytechnic State University, Pomona                        NaN
# California Polytechnic State University, San Lu...                     NaN
# ...                                                                    ...
# Solano Community College                                               NaN
# Sonoma State University                                                NaN
# Ventura College                                                        NaN
# West Valley College                                                    NaN
# Yuba College                                                           NaN
#
# [63 rows x 16 columns]

# %%
df_test_cases
# Out:
#                                                                                           MATH226 eqv  \
# School
# SFSU                                                MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# Berkeley City College                               MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# California Polytechnic State University, Humboldt   MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# California Polytechnic State University, Pomona     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# California Polytechnic State University, San Lu...  MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# ...                                                                                               ...
# Solano Community College                            MATH020:\n\n4.0 Units\nPrint\nDescription:\n\n...
# Sonoma State University                             MATH 161 - Differential and Integral Calculus ...
# Ventura College                                     MATH V21A Calculus with Analytic Geometry I 5 ...
# West Valley College                                 MATH 003A: Calculus and Analytical Geometry\nC...
# Yuba College                                        MATH-1A 4 UNITS\nSingle Variable Calculus I - ...
#
#                                                                                            CSC230 eqv  \
# School
# SFSU                                                CSC 230 - Discrete Mathematical Structures for...
# Berkeley City College                                  MATH 11 - Discrete Mathematics\n4 units\n\nN/A
# California Polytechnic State University, Humboldt   MATH 253 - Discrete Mathematics\n3 Units, 3 Le...
# California Polytechnic State University, Pomona     CS 1300 - Discrete Structures\n4 Units\nPrereq...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS021:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                     MATH V52 Discrete Structures 3 Units\nSame-As:...
# West Valley College                                 MATH 019: Discrete Mathematics\nCourse Descrip...
# Yuba College                                        COMSC-15 3 UNITS\nDiscrete Structures for Comp...
#
#                                                                                            CSC256 eqv  \
# School
# SFSU                                                CSC 256 - Machine Structures\n3 Units\n\nDigit...
# Berkeley City College                               CIS 20: Microcomputer Assembly Language\n4 Uni...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     CS 2640 - Computer Organization and Assembly P...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        COMSC-2 3 UNITS\nComputer Assembly Language\nT...
#
#                                                                                      MATH226 eqv data  \
# School
# SFSU                                                {"name": "MATH 226 - Calculus I", "discipline"...
# Berkeley City College                               ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...
# California Polytechnic State University, San Lu...  {"name": "MATH 141 - Calculus I", "discipline"...
# ...                                                                                               ...
# Solano Community College                            {"name": "MATH020", "discipline": "Mathematics...
# Sonoma State University                             ```\n{\n  "name": "MATH 161 - Differential and...
# Ventura College                                     ```\n{\n  "name": "MATH V21A Calculus with Ana...
# West Valley College                                 ```\n{\n  "name": "MATH 003A: Calculus and Ana...
# Yuba College                                        ```\n{\n  "name": "MATH-1A",\n  "discipline": ...
#
#                                                                                       CSC230 eqv data  \
# School
# SFSU                                                {"name": "CSC 230 - Discrete Mathematical Stru...
# Berkeley City College                               {"name": "MATH 11 - Discrete Mathematics", "di...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 253 - Discrete Mathema...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 1300 - Discrete Structur...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            ```\n{\n  "name": "CIS021",\n  "discipline": "...
# Sonoma State University                                                                           NaN
# Ventura College                                     ```\n{\n  "name": "MATH V52 Discrete Structure...
# West Valley College                                 ```\n{\n  "name": "MATH 019: Discrete Mathemat...
# Yuba College                                        ```\n{\n  "name": "COMSC-15",\n  "discipline":...
#
#                                                                                       CSC256 eqv data
# School
# SFSU                                                ```\n{\n  "name": "CSC 256 - Machine Structure...
# Berkeley City College                               ```\n{\n  "name": "CIS 20: Microcomputer Assem...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 2640 - Computer Organiza...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            {"name": "CIS020", "discipline": "Computer Sci...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        ```\n{\n  "name": "Computer Assembly Language"...
#
# [63 rows x 6 columns]

# %%
indices = df_test_cases.loc[:,'MATH226 eqv'].dropna().drop(columns=["School"]).sample(n=50).index

# %%
df_test_cases
# Out:
#                                                                                           MATH226 eqv  \
# School
# SFSU                                                MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# Berkeley City College                               MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# California Polytechnic State University, Humboldt   MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# California Polytechnic State University, Pomona     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# California Polytechnic State University, San Lu...  MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# ...                                                                                               ...
# Solano Community College                            MATH020:\n\n4.0 Units\nPrint\nDescription:\n\n...
# Sonoma State University                             MATH 161 - Differential and Integral Calculus ...
# Ventura College                                     MATH V21A Calculus with Analytic Geometry I 5 ...
# West Valley College                                 MATH 003A: Calculus and Analytical Geometry\nC...
# Yuba College                                        MATH-1A 4 UNITS\nSingle Variable Calculus I - ...
#
#                                                                                            CSC230 eqv  \
# School
# SFSU                                                CSC 230 - Discrete Mathematical Structures for...
# Berkeley City College                                  MATH 11 - Discrete Mathematics\n4 units\n\nN/A
# California Polytechnic State University, Humboldt   MATH 253 - Discrete Mathematics\n3 Units, 3 Le...
# California Polytechnic State University, Pomona     CS 1300 - Discrete Structures\n4 Units\nPrereq...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS021:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                     MATH V52 Discrete Structures 3 Units\nSame-As:...
# West Valley College                                 MATH 019: Discrete Mathematics\nCourse Descrip...
# Yuba College                                        COMSC-15 3 UNITS\nDiscrete Structures for Comp...
#
#                                                                                            CSC256 eqv  \
# School
# SFSU                                                CSC 256 - Machine Structures\n3 Units\n\nDigit...
# Berkeley City College                               CIS 20: Microcomputer Assembly Language\n4 Uni...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     CS 2640 - Computer Organization and Assembly P...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        COMSC-2 3 UNITS\nComputer Assembly Language\nT...
#
#                                                                                      MATH226 eqv data  \
# School
# SFSU                                                {"name": "MATH 226 - Calculus I", "discipline"...
# Berkeley City College                               ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...
# California Polytechnic State University, San Lu...  {"name": "MATH 141 - Calculus I", "discipline"...
# ...                                                                                               ...
# Solano Community College                            {"name": "MATH020", "discipline": "Mathematics...
# Sonoma State University                             ```\n{\n  "name": "MATH 161 - Differential and...
# Ventura College                                     ```\n{\n  "name": "MATH V21A Calculus with Ana...
# West Valley College                                 ```\n{\n  "name": "MATH 003A: Calculus and Ana...
# Yuba College                                        ```\n{\n  "name": "MATH-1A",\n  "discipline": ...
#
#                                                                                       CSC230 eqv data  \
# School
# SFSU                                                {"name": "CSC 230 - Discrete Mathematical Stru...
# Berkeley City College                               {"name": "MATH 11 - Discrete Mathematics", "di...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 253 - Discrete Mathema...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 1300 - Discrete Structur...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            ```\n{\n  "name": "CIS021",\n  "discipline": "...
# Sonoma State University                                                                           NaN
# Ventura College                                     ```\n{\n  "name": "MATH V52 Discrete Structure...
# West Valley College                                 ```\n{\n  "name": "MATH 019: Discrete Mathemat...
# Yuba College                                        ```\n{\n  "name": "COMSC-15",\n  "discipline":...
#
#                                                                                       CSC256 eqv data
# School
# SFSU                                                ```\n{\n  "name": "CSC 256 - Machine Structure...
# Berkeley City College                               ```\n{\n  "name": "CIS 20: Microcomputer Assem...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 2640 - Computer Organiza...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            {"name": "CIS020", "discipline": "Computer Sci...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        ```\n{\n  "name": "Computer Assembly Language"...
#
# [63 rows x 6 columns]

# %%
df_source = df_test_cases.drop(df_test_cases.columns[[0, 3]], axis=1)
df_source
# Out:
#                                                                                            CSC230 eqv  \
# School
# SFSU                                                CSC 230 - Discrete Mathematical Structures for...
# Berkeley City College                                  MATH 11 - Discrete Mathematics\n4 units\n\nN/A
# California Polytechnic State University, Humboldt   MATH 253 - Discrete Mathematics\n3 Units, 3 Le...
# California Polytechnic State University, Pomona     CS 1300 - Discrete Structures\n4 Units\nPrereq...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS021:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                     MATH V52 Discrete Structures 3 Units\nSame-As:...
# West Valley College                                 MATH 019: Discrete Mathematics\nCourse Descrip...
# Yuba College                                        COMSC-15 3 UNITS\nDiscrete Structures for Comp...
#
#                                                                                            CSC256 eqv  \
# School
# SFSU                                                CSC 256 - Machine Structures\n3 Units\n\nDigit...
# Berkeley City College                               CIS 20: Microcomputer Assembly Language\n4 Uni...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     CS 2640 - Computer Organization and Assembly P...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        COMSC-2 3 UNITS\nComputer Assembly Language\nT...
#
#                                                                                       CSC230 eqv data  \
# School
# SFSU                                                {"name": "CSC 230 - Discrete Mathematical Stru...
# Berkeley City College                               {"name": "MATH 11 - Discrete Mathematics", "di...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 253 - Discrete Mathema...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 1300 - Discrete Structur...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            ```\n{\n  "name": "CIS021",\n  "discipline": "...
# Sonoma State University                                                                           NaN
# Ventura College                                     ```\n{\n  "name": "MATH V52 Discrete Structure...
# West Valley College                                 ```\n{\n  "name": "MATH 019: Discrete Mathemat...
# Yuba College                                        ```\n{\n  "name": "COMSC-15",\n  "discipline":...
#
#                                                                                       CSC256 eqv data
# School
# SFSU                                                ```\n{\n  "name": "CSC 256 - Machine Structure...
# Berkeley City College                               ```\n{\n  "name": "CIS 20: Microcomputer Assem...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 2640 - Computer Organiza...
# California Polytechnic State University, San Lu...                                                NaN
# ...                                                                                               ...
# Solano Community College                            {"name": "CIS020", "discipline": "Computer Sci...
# Sonoma State University                                                                           NaN
# Ventura College                                                                                   NaN
# West Valley College                                                                               NaN
# Yuba College                                        ```\n{\n  "name": "Computer Assembly Language"...
#
# [63 rows x 4 columns]

# %%
df_source = pd.concat([df_source.iloc[:,0], df_source.iloc[:, 1]]).dropna().sample(n=1420, replace=True)
df_source
# Out:
# School
# Pasadena City College                       CS 066  ASSEMBLY LANGUAGE PROGRAMMING FOR THE ...
# Skyline College                             COMP 262 Discrete Mathematics for Computer Sci...
# Santa Barbara City College                  CS 107 Computer Architecture and Organization ...
# California State University, Bakersfield    CMPS 2120 - Discrete Structures\n4 Units\n\nDi...
# Sierra College                              MATH 0015. Discrete Mathematics\n\nUnits: 4\nP...
#                                                                   ...
# Gavilan College                             CSIS 26 - Discrete Structures\n3 Units\n\nTopi...
# Santa Monica College                        MATH 10\nDiscrete Structures\nUnits: 3\nTransf...
# Reedley College                             26 DISCRETE MATHEMATICS FOR\nCOMPUTER SCIENCE\...
# Mount San Antonio College                   CSCI 150  Assembly Language/Machine Architectu...
# City College of San Francisco               CS 270, Computer Architecture with Assembly La...
# Length: 1420, dtype: object

# %%
df_source = df_test_cases.drop(df_test_cases.columns[[0, 3]], axis=1)
df_source = df_test_cases.drop(df_test_cases.columns[[i, i+3]], axis=1)
source_raw_col = pd.concat([df_source.iloc[:, 0], df_source.iloc[:, 1]], axis=0).dropna().reset_index()
source_topic_col = pd.concat([df_source.iloc[:, 2], df_source.iloc[:, 3]], axis=0).dropna().reset_index()
source_indices = source_raw_col.sample(n=1420, replace=True).index

# %%
source_raw_col.iloc[source_indices, 1]
# Out:
# 14     MATH 122 - Calculus I\n4 Units\n\nPrerequisite...
# 61     MATH-1A 4 UNITS\nSingle Variable Calculus I - ...
# 60     MATH 003A: Calculus and Analytical Geometry\nC...
# 108    MATH 4 Discrete Mathematics\n\n4 Units/4 hours...
# 18     MATH 30 - Calculus I\n4 Units\nPrerequisite(s)...
#                              ...
# 58     MATH 161 - Differential and Integral Calculus ...
# 54     MATH 1A Calculus, First Course\n\n5 Units/5 ho...
# 102    CS 045  DISCRETE STRUCTURES WITH COMPUTER SCIE...
# 58     MATH 161 - Differential and Integral Calculus ...
# 28     MATH 400 - Calculus I\n5 Units\nPrerequisite: ...
# Name: 0, Length: 1420, dtype: object

# %%
source_topic_col.iloc[source_indices, 1]
# Out:
# 14     {"name": "MATH 122 - Calculus I", "discipline"...
# 61     ```\n{\n  "name": "MATH-1A",\n  "discipline": ...
# 60     ```\n{\n  "name": "MATH 003A: Calculus and Ana...
# 108    {"name": "MATH 4 Discrete Mathematics", "disci...
# 18     {"name": "MATH 30 - Calculus I", "discipline":...
#                              ...
# 58     ```\n{\n  "name": "MATH 161 - Differential and...
# 54     {"name": "MATH 1A Calculus, First Course", "di...
# 102    {"name": "CS 045  DISCRETE STRUCTURES WITH COM...
# 58     ```\n{\n  "name": "MATH 161 - Differential and...
# 28     {"name": "MATH 400 - Calculus I", "discipline"...
# Name: 0, Length: 1420, dtype: object

# %%
target_indices = df_test_cases.iloc[:,0].dropna().sample(n=1420, replace=True).index
target_indices
# target_raw = df_test_cases.iloc[target_indices, 0]
# Out:
# Index(['Mount San Antonio College',
#        'California Polytechnic State University, Pomona',
#        'California State University, Stanislaus', 'Reedley College',
#        'Merced Community College', 'California State University, Long Beach',
#        'California Polytechnic State University, Humboldt',
#        'Clovis Community College', 'Foothill College',
#        'Sonoma State University',
#        ...
#        'City College of San Francisco', 'SFSU',
#        'California State University, Dominguez Hills',
#        'California State University, Los Angeles',
#        'California Polytechnic State University, Pomona', 'SFSU',
#        'Contra Costa College', 'Grossmont College', 'Ohlone College',
#        'Chabot College'],
#       dtype='object', name='School', length=1420)

# %%
df_test_cases.loc[target_indices].iloc[:,0]
# Out:
# School
# Mount San Antonio College                          MATH 180  Calculus and Analytic Geometry I\n\n...
# California Polytechnic State University, Pomona    MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# California State University, Stanislaus            MATH 1410 - Calculus I\n4 Units\n\nInequalitie...
# Reedley College                                    5A CALCULUS I\n5 units, 5 lecture hours\nPRERE...
# Merced Community College                           MATH-04A - CALCULUS I\n4 units: 4 hours lectur...
#                                                                          ...
# SFSU                                               MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# Contra Costa College                               MATH-190 Analytic Geometry and Calculus I\n\n5...
# Grossmont College                                  MATH 180 - ANALYTIC GEOMETRY AND CALCULUS I\n5...
# Ohlone College                                     Calculus with Analytic Geometry\n90.00 hrs lec...
# Chabot College                                     MTH 1 - Calculus I\n5 Units\n\nElements of ana...
# Name: MATH226 eqv, Length: 1420, dtype: object

# %%
target_sample = []
for i in range(3):
    target_indices = df_test_cases.iloc[:,i].dropna().sample(n=1420, replace=True).index
    target_raw = df_test_cases.loc[target_indices].iloc[:,i]
    target_topic = df_test_cases.loc[target_indices].iloc[:,i+3]

    df_source = df_test_cases.drop(df_test_cases.columns[[i, i+3]], axis=1)
    source_raw_col = pd.concat([df_source.iloc[:, 0], df_source.iloc[:, 1]], axis=0).dropna().reset_index()
    source_topic_col = pd.concat([df_source.iloc[:, 2], df_source.iloc[:, 3]], axis=0).dropna().reset_index()
    source_indices = source_raw_col.sample(n=1420, replace=True).index

    target_sample.append(list(zip(target_raw, source_raw_col.iloc[source_indices, 1], target_topic, source_topic_col.iloc[source_indices, 1], [0 for i in range(len(target_indices))])))

# %%
target_sample[0]
# Out:
# [("Math 2510 - Single Variable Calculus I\n4 Units\n\nA first course in single variable calculus. \nTopics include: Definition and computation of limits using numerical, graphical, and algebraic approaches; Continuity and differential ability of functions; Derivative as a limit; Interpretation of the derivative as: slope of tangent line, a rate of change; Differentiation formulas: constants, power rule, product rule, quotient rule and chain rule; Derivatives of transcendental functions such as trigonometric, exponential or logarithmic; Implicit differentiation with applications, and differentiation of inverse functions; Higher-order derivatives; Graphing functions using first and second derivatives, concavity and asymptotes; Indeterminate forms and L'Hopital's Rule; Maximum and minimum values, and optimization; Mean Value Theorem; Antiderivatives and indefinite integrals; Area under a curve; Definite integral; Riemann sum; Properties of the integral; Fundamental Theorem of Calculus; Integration by substitution. Course makes use of a Computer Algebra System. \n\nPrerequisite: (1) C- or better in MATH 1030, MATH 1040 or MATH 1060, or (2) A score of at least 80 on the Math Placement Exam, or (3) a score of 50 on the CLEP Exam. Note: Students without recent credit in MATH 1030, MATH 1040 or MATH 1060 are advised to consult the Department of Mathematics and to take the Math Placement Exam before enrolling. This Foundational Skills course must be completed with a grade of C- or higher.",
#   'CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA hardware-oriented programming course dealing with programming a computer at the assembler language level. Emphasis will be on the assembly language of computers.\nC-ID: COMP 142\n \n\nTransferable to both UC and CSU',
#   '{"name": "Math 2510 - Single Variable Calculus I", "discipline": "Mathematics", "topics": ["Limits", "Continuity", "Derivatives", "Differentiation", "Graphing functions", "Indeterminate forms", "L\'Hopital\'s Rule", "Maximum and minimum values", "Optimization", "Mean Value Theorem", "Antiderivatives", "Area under a curve", "Definite integral", "Riemann sum", "Properties of the integral", "Fundamental Theorem of Calculus", "Integration by substitution"]}',
#   '{"name": "CIS020", "discipline": "Computer Science", "topics": ["Assembly Language"]}',
#   0),
#  ('MATH C185 - Calculus 2  \n5 Units (90 lecture hours)  \nPrerequisite(s): MATH C180 with a grade of C or better.\nGrading Mode: Standard Letter, Pass/No Pass\n\ntechniques and applications of integration, calculus applied to parametric curves and polar curves, analytic geometry, sequences, series, and an introduction to differential equations.',
#   'COMSC-260 - Assembly Language Programming/ Computer Organization\n4 units\nPrerequisite: COMSC-165 or equivalent\nThis course covers the basics of machine architecture, machine language, assembly language, operating system interface, and interfacing with high level languages. Topics include data representation, instruction representation and execution, addressing, indexing, macros, subroutine linkages, storage and time efficiency issues, interrupt descriptor tables, virtual memory, cache memory, and dynamic address translation.',
#   '```\n{\n  "name": "Calculus 2",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differential Equations", "Analytic Geometry", "Sequences", "Series"]\n}\n```',
#   '{"name": "COMSC-260 - Assembly Language Programming/ Computer Organization", "discipline": "Computer Science", "topics": ["Assembly Language", "Computer Organization", "Data Representation", "Instruction Representation and Execution", "Addressing", "Indexing", "Macros", "Subroutine Linkages", "Storage and Time Efficiency Issues", "Interrupt Descriptor Tables", "Virtual Memory", "Cache Memory", "Dynamic Address Translation"]}',
#   0),
#  ('MATH 130 - Calculus I\n4 Units\n\nIntroduction to limits and limit techniques; derivatives; related rates; optimization and applications; antiderivatives, introduction to integration and the fundamental theorem of calculus. \n\nPrerequisites: One from the following: Satisfactory score of 78 or higher on Mathematics Placement Exam, MATH 120 orÂ MATH 125 (either course with grade C- or better). Equivalent Quarter Course: Students who have taken MATH 1304 AND MATH 1305 under a recent quarter catalog will receive credit for MATH 130.',
#   'MATH 170A - Mathematical Structures I\n3 Units\n\nFirst of two semesters of fundamental discrete mathematical concepts and techniques needed in computer-related disciplines. Logic, truth tables, elementary set theory, proof techniques, combinatorics, Boolean algebra, recursion and graph theory. \n\nMust have completed four years of high school mathematics.',
#   '{"name": "MATH 130 - Calculus I", "discipline": "Mathematics", "topics": ["Calculus", "Limits", "Derivatives", "Optimization", "Antiderivatives", "Integration", "Fundamental Theorem of Calculus"]}',
#   '{"name": "MATH 170A - Mathematical Structures I", "discipline": "Computer Science", "topics": ["Logic", "Set Theory", "Proof Techniques", "Combinatorics", "Boolean Algebra", "Recursion", "Graph Theory"]}',
#   0),
#  ('MTH 210 - Calculus I\nClass Hours: 4, Units: 4\nGeneral Education: Area B4 Mathematics/Quantitative Reasoning - must meet minimum grade of C- or better in order to earn General Education credit.\nPrerequisite(s): MTH 100 or equivalent with a C- or higher\n\nIntroduction of functions and limits, differentiation, applications of differentiation, integration, and applications of the definite integral.',
#   'CECS 228 - Discrete Structures with Computing Applications\n3 Units\nPrerequisites: CECS 174 and MATH 113 or equivalent all with a grade of “C” or better.\n\nAn introduction to discrete mathematics with applications towards computing. Topics include sets, functions, logic, relations, graphs, trees, recursion, combinatorics, and mathematical reasoning.\n\nLetter grade only (A-F). (Lecture 2 hours, laboratory/problem session 3 hours). Same course as CECS 228H. Not open for credit to students with credit in CECS 228H.',
#   '```\n{\n  "name": "MTH 210 - Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differentiation", "Integration"]\n}\n```',
#   '{"name": "CECS 228 - Discrete Structures with Computing Applications", "discipline": "Computer Science", "topics": ["sets", "functions", "logic", "relations", "graphs", "trees", "recursion", "combinatorics", "mathematical reasoning"]}',
#   0),
#  ('MATH 141 - Calculus I\n4 Units\nGE Area B1\nPrerequisite: Appropriate Math Placement Level, or MATH 117 and high school trigonometry; or MATH 118 and high school trigonometry; or MATH 119.\n\nLimits, continuity, differentiation. Introduction to integration. \n4 lectures. Crosslisted a HNRS/MATH 141. Fulfills GE B1; for students admitted Fall 2016 or later, a grade of C- or better in one GE B1 course is required to fulfill GE Area B.',
#   'Introduction to Assembly Language Programming\n36.00 hrs lecture, 72.00 hrs lab\nUnits: 3.00\nPrerequisite: CS-102\nAccepted For Credit: CSU & UC\nOffered: All Terms, Every Year\nThis course is an introduction to assembly language for computers. Topics\ninclude numbering systems, architecture, native machine instructions,\nmemory addressing, subroutines, system calls, file I/O, and interaction\nbetween assembly language programs, the operating system, and other\nlanguages. (GR) C-ID COMP 142',
#   '{"name": "MATH 141 - Calculus I", "discipline": "Mathematics", "topics": ["Calculus", "Differentiation", "Integration"]}',
#   '```\n{\n  "name": "Introduction to Assembly Language Programming",\n  "discipline": "Computer Science",\n  "topics": ["Numbering Systems", "Architecture", "Native Machine Instructions", "Memory Addressing", "Subroutines", "System Calls", "File I/O", "Interaction between Assembly Language Programs, the Operating System, and Other Languages"]\n}\n```',
#   0),
#  ("MATH 1A -Single-Variable Calculus and Analytic Geometry\n4 Units\nA first course in differential and integral calculus of a single variable covering limits and continuity, analyzing\nthe behavior and graphs of functions, derivatives, implicit differentiation, higher order derivatives, related\nrates and optimization problems, Newton's Method, Fundamental Theorem of Calculus, and definite and\nindefinite integrals. (C-ID MATH 210) PREREQUISITE: Mathematics 8B or Mathematics 11 with a grade of\n'C' or better, or high school Precalculus with a grade of 'B' or better completed within the last five years, or\nequivalent skills.\n\nPREREQUISITES:\nCompletion of MATH 8B, as UG, with a grade of C or better.\nOR\nCompletion of MATH 11, as UG, with a grade of C or better.\nOR\nScore of 28 on Pre-Calculus\nOR\nScore of 2900 on Accuplacer Math ",
#   'CSCI 150  Assembly Language/Machine Architecture\n\n3.5 Units (Degree Applicable, CSU, UC)\nLecture: 54   Lab: 27\nPrerequisite: CSCI 110\nAdvisory: CSCI 140 or CSCI 145\n\nOrganization and operation of real computer systems at the assembly language level using the Intel 80x86 family of processors; mapping statements and constructs in a high-level language onto sequences of machine instructions; internal representations of simple data types and structures; numerical computation, noting various data representation errors and potential procedural errors; investigation of basic principles of operating systems; and programming language translation process.',
#   '{"name": "MATH 1A -Single-Variable Calculus and Analytic Geometry", "discipline": "Mathematics", "topics": ["Calculus", "Analytic Geometry"]}',
#   '```\n{\n  "name": "CSCI 150  Assembly Language/Machine Architecture",\n  "discipline": "Computer Science",\n  "topics": ["Assembly Language", "Machine Architecture", "Operating Systems", "Programming Language Translation"]\n}\n```',
#   0),
#  ('MATH 003A: Calculus and Analytical Geometry\nCourse Description\n\nThis is a first course in differential and integral calculus of a single variable: topics include functions; limits and continuity; techniques and applications of differentiation and integration; Fundamental Theorem of Calculus. It is designed primarily for Science, Technology, Engineering, and Math Majors.\n\nUnits: 5\n\n    Credit - Degree Applicable\n    Transferable to both UC and CSU\n\nCourse Details\n\n    Grade Options: Letter Grade\n    In-Class Lecture Hours: 80 – 90\n    In-Class Lab Hours: 0\n\nRequisites and Advisories\n\n    Prerequisites: MATH 001, MATH 000D or MATH 002\n    Co-Requisites: None\n    Advisory: None\n\nTransfer Details\n\n    CSU/UC: Transferable to both UC and CSU\n    WVC GE: A. Language and Rationality: A2 - Communication and Analytical Thinking\n    CSU GE: Area B - Scientific Inquiry and Quantitative Reasoning: B4 -Mathematics/Quantitative Reasoning\n    UC/IGETC GE: Area 2 - Mathematical Concepts and Quantitative Reasoning\n    C-ID: MATH 210 - Single Variable Calculus I Early Transcendentals',
#   'CPSC 240 - Computer Organization & Assembly Language\n3 Units\n\nDigital logic and architecture of a computer system, machine level representation of data, memory system organization, structure of low-level computer languages. Machine, assembly, and macro language programming. Principles of assembler operation, input-output programming, interrupt/exception handling. Laboratory programming assignments. \n\n(2 hours lecture, 2 hours laboratory). \nClass Notes: Students enroll in the lecture/discussion component only of a multi-component course and are AUTOMATICALLY enrolled in the associated component(s) (activity/lab). Enrollment restricted to those students who have met the prerequisite(s). (See Catalog.). \nEnrollment Requirements: Prerequisites: CPSC 131; MATH 170A or MATH 280; or graduate standing.',
#   '```\n{\n  "name": "MATH 003A: Calculus and Analytical Geometry",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Analytical Geometry"]\n}\n```',
#   '```\n{\n  "name": "CPSC 240 - Computer Organization & Assembly Language",\n  "discipline": "Computer Science",\n  "topics": ["Computer Architecture", "Assembly Language", "Machine Language", "Memory System", "Low-Level Programming"]\n}\n```',
#   0),
#  ("MATH V21A Calculus with Analytic Geometry I 5 Units\nIn-Class Hours: 87.5 lecture\nPrerequisites: Both MATH V04 and MATH V05 with grades of C or better; or MATH V20 with grade of C or better; or the fourth year of high school mathematics (advanced mathematics) with grade of C or better; or placement as determined by the college's multiple measures assessment process\nC-ID: MATH 210, MATH 900S [MATH V21A + MATH V21B]\n\nThis is a first course in differential and integral calculus of a single variable which covers the elements of calculus. Topics include functions; limits; continuity; techniques and applications of differentiation and integration of algebraic, logarithmic and trigonometric functions; the Fundamental Theorem of Calculus; and L'Hospital's rule. The course is suitable for science, technology, engineering, and mathematics majors.\nCatalog Notes: Successful completion of this course fulfills the mathematics competency requirement for the AA/AS degree.\nGrade Modes: Letter Graded\nCredit Limitations: see counselor.\nDegree Applicability: Applies to Associate Degree\nAA/AS GE: D2\nTransfer Credit: CSU, UC\nUC Credit Limitations: None\nCSU GE-Breadth: B4\nIGETC: 2A ",
#   'CIS 20 - Microcomputer Assembly Language\n\nUnits: 4\n\nClass: 3 hours lecture, 3 hours laboratory (GR or P/NP)\n\nRecommended preparation: CIS 3 or 6 or 26\nAcceptable for credit: CSU, UC\n\nDescription: Introduction to assembly language: Input/output operations, use of files, program flow controls, interaction with OS via interrupts, pointers and arrays, strings and structured programming, and related applications. 0707.10\n\nAA/AS area 4c',
#   '```\n{\n  "name": "MATH V21A Calculus with Analytic Geometry I",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differential and integral calculus", "Functions", "Limits", "Continuity", "Techniques and applications of differentiation and integration of algebraic, logarithmic and trigonometric functions", "Fundamental Theorem of Calculus", "L\'Hospital\'s rule"]\n}\n```',
#   '```\n{\n  "name": "CIS 20 - Microcomputer Assembly Language",\n  "discipline": "Computer Science",\n  "topics": ["Assembly Language", "Input/Output Operations", "Files", "Program Flow Controls", "Interrupts", "Pointers and Arrays", "Strings", "Structured Programming", "Applications"]\n}\n```',
#   0),
#  ("Math 2510 - Single Variable Calculus I\n4 Units\n\nA first course in single variable calculus. \nTopics include: Definition and computation of limits using numerical, graphical, and algebraic approaches; Continuity and differential ability of functions; Derivative as a limit; Interpretation of the derivative as: slope of tangent line, a rate of change; Differentiation formulas: constants, power rule, product rule, quotient rule and chain rule; Derivatives of transcendental functions such as trigonometric, exponential or logarithmic; Implicit differentiation with applications, and differentiation of inverse functions; Higher-order derivatives; Graphing functions using first and second derivatives, concavity and asymptotes; Indeterminate forms and L'Hopital's Rule; Maximum and minimum values, and optimization; Mean Value Theorem; Antiderivatives and indefinite integrals; Area under a curve; Definite integral; Riemann sum; Properties of the integral; Fundamental Theorem of Calculus; Integration by substitution. Course makes use of a Computer Algebra System. \n\nPrerequisite: (1) C- or better in MATH 1030, MATH 1040 or MATH 1060, or (2) A score of at least 80 on the Math Placement Exam, or (3) a score of 50 on the CLEP Exam. Note: Students without recent credit in MATH 1030, MATH 1040 or MATH 1060 are advised to consult the Department of Mathematics and to take the Math Placement Exam before enrolling. This Foundational Skills course must be completed with a grade of C- or higher.",
#   'CS 221 - Assembly Language and Computer Architecture\n3 Units\n\nPropositional logic and predicate calculus, set theory, inference, induction, recursion, divide-and-conquer, enumeration, graphs and topology, trees, binary trees and traversals, Boolean algebra, logic gates, asymptotic notation and algorithm analysis, combinatorics, cryptography, discrete probability, computational modeling.\n\nEquivalent Quarter Course: CS 2430\nGrading: A-F\n',
#   '{"name": "Math 2510 - Single Variable Calculus I", "discipline": "Mathematics", "topics": ["Limits", "Continuity", "Derivatives", "Differentiation", "Graphing functions", "Indeterminate forms", "L\'Hopital\'s Rule", "Maximum and minimum values", "Optimization", "Mean Value Theorem", "Antiderivatives", "Area under a curve", "Definite integral", "Riemann sum", "Properties of the integral", "Fundamental Theorem of Calculus", "Integration by substitution"]}',
#   '```\n{\n  "name": "CS 221 - Assembly Language and Computer Architecture",\n  "discipline": "Computer Science",\n  "topics": ["Assembly Language", "Computer Architecture"]\n}\n```',
#   0),
#  ('MATH 7\nCalculus 1\nUnits: 5\nTransfer: UC*, CSU\n\nC-ID: MATH 211.\n\nIGETC AREA 2 (Mathematical Concepts)\n\n    Prerequisite: MATH 2 or (MATH 3 and MATH 4).\n\n*Maximum UC credit for MATH 7 and MATH 28 is one course.\n\nThis first course in calculus is intended primarily for science, technology, engineering and mathematics majors. Topics include limits, continuity, and derivatives and integrals of algebraic and trigonometric functions, with mathematical and physical applications.',
#   'CS 2148 - Discrete Structures\n3 Units\n\nAn introduction to discrete mathematics with applications to Computer Science;  fundamentals of logic and set theory, counting techniques, relations, induction and recursion; graphs and trees; probability theory. Lecture 3 hours. \n\nGrading: ABC-/NC (Undergraduate Only)\nMode of Delivery: Face to Face\nCampus: Main Campus\n\nPrerequisite(s): CS 2012, MATH 2120',
#   '```\n{\n  "name": "MATH 7",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Limits", "Continuity", "Derivatives", "Integrals", "Algebraic functions", "Trigonometric functions"]\n}\n```',
#   '```\n{\n  "name": "CS 2148 - Discrete Structures",\n  "discipline": "Computer Science",\n  "topics": ["logic", "set theory", "counting techniques", "relations", "induction and recursion", "graphs and trees", "probability theory"]\n}\n```',
#   0),
#  ('MATH 30 - Calculus I\n3 unit(s)\nIntroduction to calculus including limits, continuity, differentiation, applications and introduction to integration. Graphical, algebraic and numerical methods of solving problems.\n\nSatisfies B4: Mathematics/Quantitative Reasoning.\n\nPrerequisite(s): Math Enrollment Category M-I or M-II and satisfactory score on the Precalculus Proficiency Assessment; MATH 19 with a grade of B or better to waive the exam; or MATH 18A and MATH 18B, with a grade of B or better in each to waive the exam. \nGrading: Letter Graded\n\nNote(s): Students repeating MATH 30 are not eligible for this class and must take MATH 30X, but grade forgiveness can apply. MATH 30X is replacing MATH 30P and MATH 30PL.  ',
#   'CS 2445 - Introduction to Computer Systems\n3 Units\n\nIntroduction to computer organization, Number systems and data representation; internal organization of a computer; primitive instructions and operations; logic gates; Operating Systems and Networks.  Lecture 3 hours.\n\nGrading: ABC-/NC (Undergraduate Only)\nMode of Delivery: Face to Face\nCampus: Main Campus\n\nPrerequisite(s): CS 2011',
#   '```\n{\n  "name": "MATH 30 - Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differentiation", "Integration"]\n}\n```',
#   '```\n{\n  "name": "CS 2445 - Introduction to Computer Systems",\n  "discipline": "Computer Science",\n  "topics": ["Computer Organization", "Number Systems", "Data Representation", "Internal Organization of a Computer", "Primitive Instructions and Operations", "Logic Gates", "Operating Systems", "Networks"]\n}\n```',
#   0),
#  ('MATH 180 - ANALYTIC GEOMETRY AND CALCULUS I\n5 units, 5 hours lecture\n\nPrerequisite: A "C" grade or higher in MATH 170 and 175 or MATH 176 or equivalent.\n\nMATH 180 includes topics from analytic plane geometry, limits and continuity of function, differential and integral calculus with applications involving algebraic, exponential, logarithmic, trigonometric, and hyperbolic functions. \n\nSatisfies General Education for:  \n\nGrossmont College A3; CSU B4; IGETC 2A\n\nTransfers to: CSU, UC (credit limited)',
#   'MATH 0015. Discrete Mathematics\n\nUnits: 4\nPrerequisite: Completion of MATH 30 with grade of "C" or better\nHours: 72 lecture\nStudy of set theory, relations and functions, logic, combinatorics and probability, algorithms, computability, matrix algebra, graph theory, recurrence relations, number theory including modular arithmetic. Various forms of mathematical proof are developed: proof by induction, proof by contradiction. (CSU, UC)',
#   '```\n{\n  "name": "MATH 180 - ANALYTIC GEOMETRY AND CALCULUS I",\n  "discipline": "Mathematics",\n  "topics": ["Analytic Geometry", "Calculus", "Differential Calculus", "Integral Calculus"]\n}\n```',
#   '{"name": "MATH 0015. Discrete Mathematics", "discipline": "Mathematics", "topics": ["Set Theory", "Relations and Functions", "Logic", "Combinatorics and Probability", "Algorithms", "Computability", "Matrix Algebra", "Graph Theory", "Recurrence Relations", "Number Theory", "Proof by Induction", "Proof by Contradiction"]}',
#   0),
#  ('MATH 122 - Calculus I\n4 Units\n\nPrerequisite: A grade of “C” or better in MATH 111 and either MATH 112B or MATH 113, or appropriate CSULB Algebra and Calculus Placement.\nContinuous functions. Derivatives and applications including graphing, related rates, and optimization. Transcendental functions. L’Hospital’s Rule. Antiderivatives. Definite integrals. Area under a curve.\n\nBoth grading options. (Lecture 3 hrs., problem session 2 hrs.)',
#   'COMSC-2 3 UNITS\nComputer Assembly Language\nT R A N S F E R A B L E T O C S U A N D U C\nC - I D : C O M P 1 4 2\n3 6 L E C T U R E H O U R S\n5 4 L A B H O U R S\nBasic operating principles and structure of digital computers including\naddressing mode, stack manipulation, interrupt processing, fixed\nand floating point formats, subroutines, features of assemblers,\ndirectives, symbol tables, and macros. Programs are written using\ntypical operating systems and machine language for typical modern\nprocessors. (L,M,C) Grades are P/NP Option.',
#   '{"name": "MATH 122 - Calculus I", "discipline": "Mathematics", "topics": ["Calculus", "Differential Equations", "Integrals"]}',
#   '```\n{\n  "name": "Computer Assembly Language",\n  "discipline": "Computer Science",\n  "topics": ["Computer Architecture", "Assembly Language"]\n}\n```',
#   0),
#  ('MATH 150 - Calculus I\n4 Units\nFour hours lecture per week\nPrerequisite: Passing scores on the Calculus Placement Examination or MATH 105\n\nA course in analytic geometry and calculus. Topics include elementary and transcendental functions, their properties, limits, derivatives, integrals, and mathematical modeling.',
#   'CIS 20 - Microcomputer Assembly Language\n\nUnits: 4\n\nClass: 3 hours lecture, 3 hours laboratory (GR or P/NP)\n\nRecommended preparation: CIS 3 or 6 or 26\nAcceptable for credit: CSU, UC\n\nDescription: Introduction to assembly language: Input/output operations, use of files, program flow controls, interaction with OS via interrupts, pointers and arrays, strings and structured programming, and related applications. 0707.10\n\nAA/AS area 4c',
#   '```\n{\n  "name": "MATH 150 - Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Analytic geometry", "Calculus", "Elementary functions", "Limits", "Mathematical modeling", "Transcendental functions"]\n}\n```',
#   '```\n{\n  "name": "CIS 20 - Microcomputer Assembly Language",\n  "discipline": "Computer Science",\n  "topics": ["Assembly Language", "Input/Output Operations", "Files", "Program Flow Controls", "Interrupts", "Pointers and Arrays", "Strings", "Structured Programming", "Applications"]\n}\n```',
#   0),
#  ('5A CALCULUS I\n5 units, 5 lecture hours\nPREREQUISITES: Mathematics 3A or equivalent and\nMathematics 4A or equivalent. ADVISORIES: English 1A or 1AH.\nCalculus I is the first course in differential and integral\ncalculus of a single variable. Topics include functions, limits\nand continuity, techniques and applications of differentiation\nand integration, and the Fundamental Theorem of Calculus. (A,\nCSU-GE, UC, I) (C-ID MATH 210) (C-ID MATH 900S: MATH 5A\n+ MATH 5B)',
#   'CPSC-42 COMPUTER ARCHITECTURE AND ORGANIZATION\n3 units: 2 hours lecture, 3 hours lab.\nCSU & UC Transferable\n(C-ID: COMP 142)\nPrerequisites: CPSC-06 or ENGR-14 or CPSC-14\nAdvisory: ENGL-01A\n\nThe organization and behavior of real computer systems at the assembly-language level. The mapping of statements and constructs in a high-level language onto sequences of machine instructions is studied, as well as the internal representation of simple data types and structures. Numerical computation is examined, noting the various data representation errors and potential procedural errors.',
#   '```\n{\n  "name": "Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Functions", "Limits and Continuity", "Techniques and Applications of Differentiation and Integration", "Fundamental Theorem of Calculus"]\n}\n```',
#   '```\n{\n  "name": "CPSC-42 COMPUTER ARCHITECTURE AND ORGANIZATION",\n  "discipline": "Computer Science",\n  "topics": ["Computer Architecture", "Assembly Language", "Data Representation", "Numerical Computation"]\n}\n```',
#   0),
#  ("Math 2510 - Single Variable Calculus I\n4 Units\n\nA first course in single variable calculus. \nTopics include: Definition and computation of limits using numerical, graphical, and algebraic approaches; Continuity and differential ability of functions; Derivative as a limit; Interpretation of the derivative as: slope of tangent line, a rate of change; Differentiation formulas: constants, power rule, product rule, quotient rule and chain rule; Derivatives of transcendental functions such as trigonometric, exponential or logarithmic; Implicit differentiation with applications, and differentiation of inverse functions; Higher-order derivatives; Graphing functions using first and second derivatives, concavity and asymptotes; Indeterminate forms and L'Hopital's Rule; Maximum and minimum values, and optimization; Mean Value Theorem; Antiderivatives and indefinite integrals; Area under a curve; Definite integral; Riemann sum; Properties of the integral; Fundamental Theorem of Calculus; Integration by substitution. Course makes use of a Computer Algebra System. \n\nPrerequisite: (1) C- or better in MATH 1030, MATH 1040 or MATH 1060, or (2) A score of at least 80 on the Math Placement Exam, or (3) a score of 50 on the CLEP Exam. Note: Students without recent credit in MATH 1030, MATH 1040 or MATH 1060 are advised to consult the Department of Mathematics and to take the Math Placement Exam before enrolling. This Foundational Skills course must be completed with a grade of C- or higher.",
#   'CS 107 Computer Architecture and Organization (3 Units)\n\nPrerequisites: CS 105.\n\nHours: 90 (36 lecture, 54 lab)\n\nThe organization and behavior of real computer systems at the assembly-language level. The mapping of statements and constructs in a high-level language into sequences of machine instructions is studied, as well as the internal representation of simple data types, pointers, structures, and non-numeric data. Numerical computation is also examined.\n\nTransfer Information: CSU Transferable, UC Transferable\n\nC-ID: COMP 142.',
#   '{"name": "Math 2510 - Single Variable Calculus I", "discipline": "Mathematics", "topics": ["Limits", "Continuity", "Derivatives", "Differentiation", "Graphing functions", "Indeterminate forms", "L\'Hopital\'s Rule", "Maximum and minimum values", "Optimization", "Mean Value Theorem", "Antiderivatives", "Area under a curve", "Definite integral", "Riemann sum", "Properties of the integral", "Fundamental Theorem of Calculus", "Integration by substitution"]}',
#   '```\n{\n  "name": "CS 107 Computer Architecture and Organization",\n  "discipline": "Computer Science",\n  "topics": ["Computer Architecture", "Assembly Language", "Data Types", "Pointers", "Structures", "Numerical Computation"]\n}\n```',
#   0),
#  ('MATH-120 5 Units\tCalculus I\n90 hours lecture; 90 hours total\n\nPrerequisite: Completion of MATH-106 and MATH-108 with a minimum grade of C or appropriate placement.\n\nMath 120 is the first semester of a three course sequence in differential and integral calculus. Topics include functions, limits and continuity, techniques and applications of differentiation and integration, and the Fundamental Theorem of Calculus. Primarily for students majoring in mathematics, engineering or sciences. A Graphing Calculator is required.\n\nTransfers to both UC/CSU',
#   'MATH 070     Discrete Mathematics     4 Units\n\nStudents prepare for further study in mathematics, computer science, or other sciences. Students will learn and apply concepts and ideas in logic, Boolean algebra, methods of proofs, induction, sequences, set theory, counting techniques, probability, recursion, relations, graphs, and trees. (C-ID MATH 160)\n\nLecture Hours: 4  Lab Hours: None  Repeatable: No  Grading: L\n\nPrerequisite: (MATH 021 and MATH 022) or MATH 025, all with C or better, or equivalent\n\nAdvisory Level: Read: 3 Write: 3 Math: None\n\nTransfer Status: CSU/UC     Degree Applicable: AA/AS\n\nCSU GE: B4   IGETC: 2A   District GE: B4\n\nCredit by Exam: Yes',
#   '{"name": "MATH-120", "discipline": "Mathematics", "topics": ["Functions", "Limits and Continuity", "Techniques and Applications of Differentiation and Integration", "Fundamental Theorem of Calculus"]}',
#   '```\n{\n  "name": "MATH 070",\n  "discipline": "Mathematics",\n  "topics": ["logic", "Boolean algebra", "methods of proofs", "induction", "sequences", "set theory", "counting techniques", "probability", "recursion", "relations", "graphs", "trees"]\n}\n```',
#   0),
#  ('MATH 150 - Calculus I\n4 Units\nFour hours lecture per week\nPrerequisite: Passing scores on the Calculus Placement Examination or MATH 105\n\nA course in analytic geometry and calculus. Topics include elementary and transcendental functions, their properties, limits, derivatives, integrals, and mathematical modeling.',
#   'COMP 262 Discrete Mathematics for Computer Science\nCourse Description\n\nCovers the fundamental mathematical elements of computer science including mathematical logic, sets, functions and relations, generating functions, combinatorics, methods of mathematical proof, basic number theory, algorithms, graphs, and trees.\nUnits: 3\nDegree Credit\nLetter Grade Only\n\n    Lecture hours/semester: 48-54\n    Homework hours/semester: 96-108\n    Total Student Learning hours/semester: 144-162\n\nPrerequisites: Successful completion of Intermediate Algebra or equivalent, or placement by other measures as applicable and COMP 250 or COMP 284 or equivalent.\nCorequisites: None\nAA/AS Degree Requirements: Area 9A3\nTransfer Credit: CSU (CSU GE Area B4), UC (IGETC Area 2A)\nC-ID: COMP 152',
#   '```\n{\n  "name": "MATH 150 - Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Analytic geometry", "Calculus", "Elementary functions", "Limits", "Mathematical modeling", "Transcendental functions"]\n}\n```',
#   '```\n{\n  "name": "COMP 262 Discrete Mathematics for Computer Science",\n  "discipline": "Computer Science",\n  "topics": ["Mathematical logic", "Sets", "Functions and relations", "Generating functions", "Combinatorics", "Methods of mathematical proof", "Basic number theory", "Algorithms", "Graphs", "Trees"]\n}\n```',
#   0),
#  ('MATH 5A - Math Analysis I\n5 Units\nPrerequisite: MATH 4A and MATH 4B\n\nintroduction to calculus, analytic geometry, differentiation and integration of polynomial, exponential, logarithmic and trigonometric functions; limits; curve sketching and applications.',
#   'CSC 28 - Discrete Structures for Computer Science\n3 Units\nPrerequisite(s): Score of 76 or higher on ALEKS PPL exam or MATH 26A or MATH 29 or MATH 29B or MATH 30; and CSC 20. CSC 20 and MATH 30 may be taken concurrently.\n\nTerm Typically Offered: Fall, Spring\n\nIntroduction to the essential discrete structures used in Computer Science, with emphasis on their applications. Topics include: counting methods, elementary formal logic and set theory, recursive programming, digital logic and combinational circuits, real number representation, regular expressions, finite automata.',
#   '{"name": "MATH 5A - Math Analysis I", "discipline": "Mathematics", "topics": ["Calculus", "Analytic Geometry", "Differentiation", "Integration", "Limits", "Curve Sketching", "Applications"]}',
#   '{"name": "CSC 28 - Discrete Structures for Computer Science", "discipline": "Computer Science", "topics": ["counting methods", "elementary formal logic and set theory", "recursive programming", "digital logic and combinational circuits", "real number representation", "regular expressions", "finite automata"]}',
#   0),
#  ('MATH 0030. Analytical Geometry and Calculus I\n\nUnits: 4\nPrerequisite: Completion of MATH 12 and MATH 27, or MATH 29 with grades of "C" or better, or placement by matriculation assessment process\nHours: 72 lecture\nIntroduction to differential and integral calculus. Content includes limits, continuity, differentiation and integration of algebraic, trigonometric, exponential, logarithmic, hyperbolic and other transcendental functions; as well as application problems. (C-ID MATH 210) (combined with MATH 31, C-ID MATH 900S) (CSU, UC-with unit limitation)',
#   'CS 2148 - Discrete Structures\n3 Units\n\nAn introduction to discrete mathematics with applications to Computer Science;  fundamentals of logic and set theory, counting techniques, relations, induction and recursion; graphs and trees; probability theory. Lecture 3 hours. \n\nGrading: ABC-/NC (Undergraduate Only)\nMode of Delivery: Face to Face\nCampus: Main Campus\n\nPrerequisite(s): CS 2012, MATH 2120',
#   '```\n{\n  "name": "MATH 0030. Analytical Geometry and Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differential Equations", "Trigonometry"]\n}\n```',
#   '```\n{\n  "name": "CS 2148 - Discrete Structures",\n  "discipline": "Computer Science",\n  "topics": ["logic", "set theory", "counting techniques", "relations", "induction and recursion", "graphs and trees", "probability theory"]\n}\n```',
#   0),
#  ('MATH020:\n\n4.0 Units\nPrint\nDescription:\n\nFirst of the three-semester sequence in Analytic Geometry and Calculus for students majoring in mathematics, engineering, and most physical sciences, is the study of the differential and integral calculus of functions of one variable. Topics covered are limits, continuity, differentiation of algebraic and transcendental functions, applications of the derivative, definite and indefinite integrals, fundamental theorem of calculus, and applications of the definite integral.\n\nC-ID: MATH 210\n\nGeneral Education:\n\nSCC: Area B\nIGETC: Area 2\nCSU: Area B4\n\nTransferable to both UC and CSU',
#   'CS 066  ASSEMBLY LANGUAGE PROGRAMMING FOR THE SCIENCES AND MATHEMATICS  \n4 unit  \n\nTransfer Credit: CSU; UC\nPrerequisite(s): CS 002\n\nNumber systems and their rules for arithmetic; basic computer organization concepts; register manipulation, pseudocode development; instruction formats, addressing modes, parameter passing using a stack frame; assemblers and linkage editors; modular program design and development. For Computer Science, Computer Engineering, Mathematics, and Science majors, but open to all qualified students. Total of 54 hours lecture and 54 hours laboratory.\nGrade Mode: Audit, Letter Grade',
#   '{"name": "MATH020", "discipline": "Mathematics", "topics": ["Differential and integral calculus", "Functions of one variable", "Limits", "Continuity", "Differentiation", "Applications of the derivative", "Definite and indefinite integrals", "Fundamental theorem of calculus", "Applications of the definite integral"]}',
#   '```\n{\n  "name": "CS 066  ASSEMBLY LANGUAGE PROGRAMMING FOR THE SCIENCES AND MATHEMATICS",\n  "discipline": "Computer Science",\n  "topics": ["Assembly Language", "Computer Organization", "Programming"]\n}\n```',
#   0),
#  ('MATH 1A - Calculus\n5 Units\n\nAnalyze and synthesize the concepts of limits, continuity, and differentiation from a graphical, numerical, analytical and verbal approach, using correct notation and mathematical precision.\nEvaluate the behavior of graphs in the context of limits, continuity and differentiability.\nRecognize, diagnose, and decide on the appropriate method for solving applied real world problems in optimization, related rates and numerical approximation.\n\nPREREQUISITES: MATH 32, MATH 32H, MATH 43 or MATH 43H with a grade of C or better, or appropriate score on Calculus Placement Test within the past calendar year',
#   'CS 51  (C-ID COMP 142)         3 units  \nIntroduction to Computer Architecture  \n54 hours lecture, 18 hours laboratory  \nPrerequisite: CS 11 or CS 21 or CS 31 or COSP 8 and MATH 50  \nGrading: letter grade.  \nThis course covers the organization and behavior of real computer systems at the assembly-language level. The mapping of statements and constructs in a high-level language onto sequences of machine instructions is studied, as well as the internal representation of simple data types and structures. Numerical computation is examined, noting the various data representation errors and potential procedural errors. This course is modeled after the State C-ID COMP 142 course standard.\n\nTransferable to both UC and CSU; see counselor for limitations  ',
#   '{"name": "MATH 1A - Calculus", "discipline": "Mathematics", "topics": ["Calculus", "Differentiation", "Optimization", "Related Rates", "Numerical Approximation"]}',
#   '```\n{\n  "name": "CS 51",\n  "discipline": "Computer Science",\n  "topics": ["Computer Architecture", "Assembly Language", "Data Representation", "Numerical Computation"]\n}\n```',
#   0),
#  ('MAT 003A ANALYTIC GEOMETRY AND\nCALCULUS I 5.0 UNITS\nTotal Lecture: 90 hours\nPrerequisite: (MAT 000D and MAT 001) or MAT 002\nAcceptable for credit: California State University; University of\nCalifornia\nThis is the first part of the three-semester calculus sequence for\nmath, physics and engineering majors. Course topics include\nfunctions, limits, continuity, differentiation and integration, maxima,\nminima, and other applications, and the relationship between\ncalculus and analytic geometry for polynomial and transcendental\nfunctions. This course is approved for credit by exam. Pass/No Pass\nOption. C-ID # MATH 210. CSUGE: B4; IGETC: 2A.',
#   'CISP 310 Assembly Language Programming for Microcomputers\n3 Units\nPrerequisite: CISP 360 with a grade of "C" or better\n\nThis course is an introduction to computer architecture using assembly language programs. Topics include: binary representation of data and instructions, memory addressing modes, subroutines and macros, operating system interrupts, processor architecture, and interfacing with high level languages.',
#   '```\n{\n  "name": "MAT 003A ANALYTIC GEOMETRY AND CALCULUS I",\n  "discipline": "Mathematics",\n  "topics": ["Functions", "Limits", "Continuity", "Differentiation", "Integration", "Maxima", "Minima", "Applications", "Calculus", "Analytic Geometry"]\n}\n```',
#   '{\n  "name": "CISP 310 Assembly Language Programming for Microcomputers",\n  "discipline": "Computer Science",\n  "topics": [\n    "binary representation of data and instructions",\n    "memory addressing modes",\n    "subroutines and macros",\n    "operating system interrupts",\n    "processor architecture",\n    "interfacing with high level languages"\n  ]\n}',
#   0),
#  ('MATH 1A Calculus, First Course\n\n5 Units/5 hours lecture. Grade Only. Prerequisite: Completion of MATH 27 or higher (MATH); OR Course Completion of MATH 25 and MATH 58; OR AB705 placement into Math Tier 4.\nTransferability: CSU;UC.\nC-ID: MATH 900S Series\nGE: AA/AS areas B,MC;CSU area B4;IGETC area 2A\nDescription: Limits and continuity, differentiation, applications of the derivative, integration, applications of the integral.',
#   'CS 2148 - Discrete Structures\n3 Units\n\nAn introduction to discrete mathematics with applications to Computer Science;  fundamentals of logic and set theory, counting techniques, relations, induction and recursion; graphs and trees; probability theory. Lecture 3 hours. \n\nGrading: ABC-/NC (Undergraduate Only)\nMode of Delivery: Face to Face\nCampus: Main Campus\n\nPrerequisite(s): CS 2012, MATH 2120',
#   '{"name": "MATH 1A Calculus, First Course", "discipline": "Mathematics", "topics": ["Calculus", "Differentiation", "Integration"]}',
#   '```\n{\n  "name": "CS 2148 - Discrete Structures",\n  "discipline": "Computer Science",\n  "topics": ["logic", "set theory", "counting techniques", "relations", "induction and recursion", "graphs and trees", "probability theory"]\n}\n```',
#   0),
#  ('MATH 2110 - Calculus I\n4 Units\n\nFunctions, graphs, limits, continuity, derivatives, applications of the derivative, anti-differentiation, definite integral, Fundamental Theorem of Calculus, integration by substitution, applications of the integral.\n\nGrading: ABCDF\nMode of Delivery: Face to Face\nCampus: Main Campus\n\nPrerequisite(s): Scored satisfactory on placement examination or graded C or better in either MATH 1040 or (MATH 1081 and MATH 1083) or (MATH 1082 and MATH 1083) or (ESM 1082 and MATH 1083).  Corequisite(s): MATH 2111 if any of the listed prerequisites is graded less than B-.',
#   'COMSC-230 - Discrete Mathematical Structures for Computer Science\n3 units\nPrerequisite: COMSC-165, COMSC-140 or equivalent\n\nThe course content includes functions, relations and sets, and propositional and predicate logic. Methods of proof, induction, fundamentals of counting, graphs, trees, and discrete probability are also covered.',
#   '```\n{\n  "name": "MATH 2110 - Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Functions", "Graphs", "Limits", "Continuity", "Derivatives", "Applications of the Derivative", "Anti-differentiation", "Definite Integral", "Fundamental Theorem of Calculus", "Integration by Substitution", "Applications of the Integral"]\n}\n```',
#   '```\n{\n  "name": "COMSC-230 - Discrete Mathematical Structures for Computer Science",\n  "discipline": "Computer Science",\n  "topics": ["Functions", "Relations and Sets", "Propositional and Predicate Logic", "Methods of Proof", "Induction", "Fundamentals of Counting", "Graphs", "Trees", "Discrete Probability"]\n}\n```',
#   0),
#  ('MATH C185 - Calculus 2  \n5 Units (90 lecture hours)  \nPrerequisite(s): MATH C180 with a grade of C or better.\nGrading Mode: Standard Letter, Pass/No Pass\n\ntechniques and applications of integration, calculus applied to parametric curves and polar curves, analytic geometry, sequences, series, and an introduction to differential equations.',
#   'COMP 122 - Computer Architecture and Assembly Language\n1 Unit\nPrerequisites: Grade of “C-” or better in COMP 110/L or COMP 111B/L; Grade of “C-” or better in MATH 103, MATH 104, MATH 105, MATH 150A or MATH 255A; Lower division writing requirement. Corequisite: COMP 122L. \n\nIntroduction to computer architecture, assembly language programming, system software and computer applications. Number systems and data representation. Internal organization of a computer. Primitive instructions and operations. Assembly language. Integrated lecture/lab environment. \nLab: 3 hours per week.',
#   '```\n{\n  "name": "Calculus 2",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differential Equations", "Analytic Geometry", "Sequences", "Series"]\n}\n```',
#   '```\n{\n  "name": "COMP 122 - Computer Architecture and Assembly Language",\n  "discipline": "Computer Science",\n  "topics": ["Computer Architecture", "Assembly Language", "System Software", "Computer Applications", "Number Systems", "Data Representation", "Internal Organization of a Computer", "Primitive Instructions and Operations", "Assembly Language"]\n}\n```',
#   0),
#  ('MATH 75 - Calculus I\n4 Units\nPrerequisite: mathematics placement category I or II, and calculus placement according to department standards\nNo credit if taken after MATH 76. \n\nFunctions, graphs, limits, continuity, derivatives and applications, definite and indefinite integrals. G.E. Foundation B4.\n\nWeekly Lecture Hours: 3\nWeekly Lab/Activity Hours: 2',
#   'CIS021:\n\n3.0 Units\nPrint\nDescription:\n\nAn introduction to the discrete structures used in Computer Science with an emphasis on their applications. Topics covered include: Functions, Relations and Sets; Basic Logic; Proof Techniques; Basics of Counting; Graphs and Trees; and Discrete Probability.\n\nC-ID: COMP 152\n\nGeneral Education:\n\nIGETC: Area 2\n\nTransferable to both UC and CSU',
#   '```\n{\n  "name": "MATH 75 - Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Functions", "Graphs", "Limits", "Continuity", "Derivatives", "Applications", "Definite and Indefinite Integrals"]\n}\n```',
#   '```\n{\n  "name": "CIS021",\n  "discipline": "Computer Science",\n  "topics": ["Functions", "Relations and Sets", "Basic Logic", "Proof Techniques", "Basics of Counting", "Graphs and Trees", "Discrete Probability"]\n}\n```',
#   0),
#  ('MATH 400 - Calculus I\n5 Units\nPrerequisite: MATH 370 (Precalculus) with a grade of "C" or better or by eligibility determined through the placement process.\nTransferable: CSU; UC (1) MATH 341, 350, 355 and 400 combined: maximum transfer credit of one course; 2) MATH 350, 351, 355, 356, 400, 401, & 402 combined: maximum transfer credit of one series. )\n\nThis course explores the basic concepts of analytic geometry, limits (including indeterminate forms), continuity, derivatives, and integrals. Topics covered will include the graphs, derivatives, and integrals of algebraic, trigonometric, exponential, logarithmic, hyperbolic functions, and piecewise functions. Many applications will be covered, including those involving rectilinear motion, differentials, related rates, graphing, and optimization.',
#   'CS 17 - Discrete Mathematical Structures\n4 units\n\nDesigned for majors in mathematics and computer science, this course provides an introduction to discrete mathematical structures used in Computer Science and their applications. Course content includes: Propositional and predicate logic; rules of inference; quantifiers; elements of integer number theory; set theory; methods of proof; induction; combinatorics and discrete probability; functions and relations; recursive definitions and recurrence relations; elements of graph theory and trees. Applications include: analysis of algorithms, Boolean algebras and digital logic circuits. Students who have completed, or are enrolled in, MATH 10 may not receive credit. \n\nPrerequisites: MATH 1 with a minimum grade of C (may be taken concurrently), CS 1 with a minimum grade of C (may be taken concurrently). 72 hours lecture, 18 hours laboratory. AA/AS GE. Transfer: CSU, UC; CSU GE: B4; IGETC: 2A; C-ID# COMP 152.\n\nDegree Applicable, Credit\nGrading Option: GR',
#   '{"name": "MATH 400 - Calculus I", "discipline": "Mathematics", "topics": ["Analytic geometry", "Limits", "Continuity", "Derivatives", "Integrals", "Algebraic functions", "Trigonometric functions", "Exponential functions", "Logarithmic functions", "Hyperbolic functions", "Piecewise functions", "Rectilinear motion", "Differentials", "Related rates", "Graphing", "Optimization"]}',
# ...
#   'CSCI 26 - Discrete Mathematics for Computer Science\n4 Units\n\nThis course studies elements of discrete mathematics which have applications to computer science. Topics include sets, propositional and predicate logic, relations and functions, proof techniques, graph, trees, and discrete probability.\n\nPrerequisite: CSCI 41 (Programming Concepts and Methodology II)',
#   '{"name": "MATH 066 - Calculus I Late Transcendentals for STEM", "discipline": "Mathematics", "topics": ["Calculus", "Differentiation", "Integration", "Limits", "Continuity"]}',
#   '```\n{\n  "name": "CSCI 26 - Discrete Mathematics for Computer Science",\n  "discipline": "Computer Science",\n  "topics": ["sets", "propositional and predicate logic", "relations and functions", "proof techniques", "graph", "trees", "discrete probability"]\n}\n```',
#   0),
#  ('MTH 1 - Calculus I\n5 Units\n\nElements of analytic geometry, derivatives, limits and continuity, differentiation of algebraic and trigonometric functions, the definite integral.\n\nPrerequisite: MTH 20 or MTH 22 or both College Algebra ( MTH 21 or MTH 31 or MTH 31S ) and Trigonometry ( MTH 36 or MTH 36S or MTH 37 ) or an appropriate skill level demonstrated through the mathematics assessment process.',
#   'MATH V52 Discrete Structures 3 Units\nSame-As: CS V17\nIn-Class Hours: 52.5 lecture\nPrerequisites: MATH V20 or both MATH V04 and MATH V05 or MATH V19 or placement as measured by the college assessment process\nAdvisories/Rec Prep: CS V11 or equivalent\nC-ID: MATH 160, COMP 152\n\nThis course introduces the student to discrete mathematics as it is used in computer science. Topics include formal logic, proofs, sets, combinatorics, probability, functions, graph theory, Boolean Algebra, and Modeling with programming.\nGrade Modes: Letter Graded\nField Trips: May be required\nCredit Limitations: see counselor.\nDegree Applicability: Applies to Associate Degree\nAA/AS GE: D2\nTransfer Credit: CSU, UC\nUC Credit Limitations: None\nCSU GE-Breadth: B4\nIGETC: 2A ',
#   '{"name": "MTH 1 - Calculus I", "discipline": "Mathematics", "topics": ["Calculus", "Differentiation", "Integration"]}',
#   '```\n{\n  "name": "MATH V52 Discrete Structures",\n  "discipline": "Mathematics",\n  "topics": [\n    "formal logic",\n    "proofs",\n    "sets",\n    "combinatorics",\n    "probability",\n    "functions",\n    "graph theory",\n    "Boolean Algebra",\n    "Modeling with programming"\n  ]\n}\n```',
#   0),
#  ('MATH 30 - Calculus I\n3 unit(s)\nIntroduction to calculus including limits, continuity, differentiation, applications and introduction to integration. Graphical, algebraic and numerical methods of solving problems.\n\nSatisfies B4: Mathematics/Quantitative Reasoning.\n\nPrerequisite(s): Math Enrollment Category M-I or M-II and satisfactory score on the Precalculus Proficiency Assessment; MATH 19 with a grade of B or better to waive the exam; or MATH 18A and MATH 18B, with a grade of B or better in each to waive the exam. \nGrading: Letter Graded\n\nNote(s): Students repeating MATH 30 are not eligible for this class and must take MATH 30X, but grade forgiveness can apply. MATH 30X is replacing MATH 30P and MATH 30PL.  ',
#   'CS 211 - Discrete Structures\n3 Units\n\nPropositional logic and predicate calculus, set theory, inference, induction, recursion, divide-and-conquer, enumeration, graphs and topology, trees, binary trees and traversals, Boolean algebra, logic gates, Â asymptotic notation and algorithm analysis, combinatorics, cryptography, discrete probability, computational modeling. \n\nPrerequisites: MATH 130 with grade C- or better. Grading: A-F grading only. Cross-listed: MATH 211. Equivalent Quarter Course: MATH 2150.',
#   '```\n{\n  "name": "MATH 30 - Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differentiation", "Integration"]\n}\n```',
#   '{"name": "CS 211 - Discrete Structures", "discipline": "Computer Science", "topics": ["logic", "set theory", "recursion", "divide-and-conquer", "enumeration", "graphs", "trees", "Boolean algebra", "logic gates", "asymptotic notation", "algorithm analysis", "combinatorics", "cryptography", "discrete probability", "computational modeling"]}',
#   0),
#  ('MATH 0030. Analytical Geometry and Calculus I\n\nUnits: 4\nPrerequisite: Completion of MATH 12 and MATH 27, or MATH 29 with grades of "C" or better, or placement by matriculation assessment process\nHours: 72 lecture\nIntroduction to differential and integral calculus. Content includes limits, continuity, differentiation and integration of algebraic, trigonometric, exponential, logarithmic, hyperbolic and other transcendental functions; as well as application problems. (C-ID MATH 210) (combined with MATH 31, C-ID MATH 900S) (CSU, UC-with unit limitation)',
#   'COMP 256 - Discrete Structures for Computer Science\n3 Units\nPrerequisites: Grade of “C-” or better in each of COMP 182/L, MATH 150A, and PHIL 230. Corequisite: COMP 256L. \n\nStudy of discrete mathematical structures and proof techniques as used in computer science. Discrete structures, such as functions, relations, sets, graphs and trees. Proof techniques, such as proof by induction, proof by contradiction and proof by cases. Counting techniques. \nLab: 3 hours per week.',
#   '```\n{\n  "name": "MATH 0030. Analytical Geometry and Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differential Equations", "Trigonometry"]\n}\n```',
#   '```\n{\n  "name": "COMP 256 - Discrete Structures for Computer Science",\n  "discipline": "Computer Science",\n  "topics": ["Discrete Structures", "Proof Techniques", "Functions", "Relations", "Sets", "Graphs", "Trees", "Proof by Induction", "Proof by Contradiction", "Proof by Cases", "Counting Techniques"]\n}\n```',
#   0),
#  ('MATH 103E - CALCULUS AND ANALYTIC GEOMETRY I\n5 Units\nMATH 103E is the first of a sequence of three courses combining the subject matter of analytic geometry and calculus. Functions and their graphs are studied with special attention to diff erentiation, limits, rules and integration using various techniques. The calculus of inverse functions and transcendental functions as well as applications of differentiation is also covered. Lecture 5 hours. \n\nPrerequisite: Placement is based on academic background or satisfactory completion of MATH 110 or 110B. \nTransfer Credit: CSU, UC, USC. (C-ID MATH 210)',
#   'COMP 262 Discrete Mathematics for Computer Science\nCourse Description\n\nCovers the fundamental mathematical elements of computer science including mathematical logic, sets, functions and relations, generating functions, combinatorics, methods of mathematical proof, basic number theory, algorithms, graphs, and trees.\nUnits: 3\nDegree Credit\nLetter Grade Only\n\n    Lecture hours/semester: 48-54\n    Homework hours/semester: 96-108\n    Total Student Learning hours/semester: 144-162\n\nPrerequisites: Successful completion of Intermediate Algebra or equivalent, or placement by other measures as applicable and COMP 250 or COMP 284 or equivalent.\nCorequisites: None\nAA/AS Degree Requirements: Area 9A3\nTransfer Credit: CSU (CSU GE Area B4), UC (IGETC Area 2A)\nC-ID: COMP 152',
#   '{"name": "MATH 103E - CALCULUS AND ANALYTIC GEOMETRY I", "discipline": "Mathematics", "topics": ["Calculus", "Analytic Geometry"]}',
#   '```\n{\n  "name": "COMP 262 Discrete Mathematics for Computer Science",\n  "discipline": "Computer Science",\n  "topics": ["Mathematical logic", "Sets", "Functions and relations", "Generating functions", "Combinatorics", "Methods of mathematical proof", "Basic number theory", "Algorithms", "Graphs", "Trees"]\n}\n```',
#   0),
#  ('MATH 150A - Calculus I\n4 Units\n\nProperties of functions. The limit, derivative and definite integral concepts; applications of the derivative, techniques and applications of integration. \n\nSix units of credit are given for both MATH 130 and MATH 150A, or for both MATH 135 and MATH 150A. Biology, geology and earth science majors who pass ALEKS must take MATH 130. CBE majors who pass ALEKS must take MATH 135.\nPrerequisite: passing score on ALEKS; or passing score or exemption on MQE; or MATH 125 with “C” (2.0) or better.',
#   'COMSC-230 - Discrete Mathematical Structures for Computer Science\n3 units\nPrerequisite: COMSC-165, COMSC-140 or equivalent\n\nThe course content includes functions, relations and sets, and propositional and predicate logic. Methods of proof, induction, fundamentals of counting, graphs, trees, and discrete probability are also covered.',
#   '```\n{\n  "name": "MATH 150A - Calculus I",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Limits", "Derivatives", "Integrals"]\n}\n```',
#   '```\n{\n  "name": "COMSC-230 - Discrete Mathematical Structures for Computer Science",\n  "discipline": "Computer Science",\n  "topics": ["Functions", "Relations and Sets", "Propositional and Predicate Logic", "Methods of Proof", "Induction", "Fundamentals of Counting", "Graphs", "Trees", "Discrete Probability"]\n}\n```',
#   0),
#  ("MATH 150 Calculus with Analytic Geometry I (5 Units)\n\nPrerequisites: MATH 138 or equivalent based on SBCC's Assessment Center placement via multiple measures.\n\nHours: 90 (90 lecture)\n\nLimits, derivatives and integrals of algebraic, trigonometric, exponential and logarithmic functions. Differentials and applications of the derivative.\n\nSBCC General Education: SBCCGE Area D2, SBCCGE Area E1\n\nTransfer Information: CSUGE Area B4, IGETC Area 2A, CSU Transferable, UC Transferable\n\nUC Transfer Limit: MATH 130 and 150 combined: maximum credit, one course.\n\nC-ID: MATH 210.",
#   '45 COMPUTER ORGANIZATION AND\nASSEMBLY LANGUAGE\nPROGRAMMING\n4 units, 3 lecture hours, 2 lab hours,\npass/no pass\nPREREQUISITE: Computer Science 41. ADVISORY:\nEnglish 1A or English 1AH.\nThis course introduces functional organization of digital\ncomputers and low level programming; internal representation\nof data, binary arithmetic, machine instructions, addressing\nmodes, subroutine linkage, macros and interrupts, PC Assembly\nlanguage programming. (A, CSU, UC) (C-ID COMP 142',
#   '```\n{\n  "name": "MATH 150 Calculus with Analytic Geometry I",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differentials", "Integrals"]\n}\n```',
#   '{"name": "Computer Organization and Assembly Language Programming", "discipline": "Computer Science", "topics": ["Computer Organization", "Assembly Language Programming"]}',
#   0),
#  ('MATH 066 - Calculus I Late Transcendentals for STEM     \n4 Units\n\nThis is the first course in calculus for students majoring in Computer Science, Data Science, or Economics, as well as the Natural Sciences, Technology, Engineering and Mathematics. Students will study functions, limits, continuity, techniques and applications of differentiation and integration, and the Fundamental Theorem of Calculus. (C-ID MATH 211)\n\nLecture Hours: 4  Lab Hours: None  Repeatable: No  Grading: L\n\nPrerequisite: MATH 021 and MATH 022 or MATH 025 all with C or better',
#   'CSIS-213  Discrete Structures  \n\n3 Units (LEC 48-54)\n\nThis course is an introduction to the discrete structures used in Computer Science with an emphasis on their applications. Topics covered include: Functions, Relations and Sets; Basic Logic; Proof Techniques; Basics of Counting; Graphs and Trees; and Discrete Probability.\n\nPrerequisite: CSIS-113A or CSIS-113B (with a grade of C or better).\n\nTransfers to both UC/CSU\n\nC-ID: COMP 152\n\nIGETC Area(s): 2A\n\nCSU Area(s): B4 ',
#   '{"name": "MATH 066 - Calculus I Late Transcendentals for STEM", "discipline": "Mathematics", "topics": ["Calculus", "Differentiation", "Integration", "Limits", "Continuity"]}',
#   '```\n{\n  "name": "CSIS-213  Discrete Structures",\n  "discipline": "Computer Science",\n  "topics": ["Functions", "Relations and Sets", "Basic Logic", "Proof Techniques", "Basics of Counting", "Graphs and Trees", "Discrete Probability"]\n}\n```',
#   0),
#  ('MATH 3A - Calculus I\n5 Units\nPrerequisite: MATH 002; or MATH 001, and MATH\n050; or appropriate placement through multiple\nmeasure assessment process\n\nTheorems on limits and continuous functions,\nderivatives, differentials and applications: Fundamental\ntheorems of calculus and applications; properties of\nexponential, logarithmic, and inverse trigonometric\nfunctions, and hyperbolic functions.',
#   'MATH 217 - Discrete Mathematics\n3 Units\nPrerequisite: GE Mathematics/Quantitative Reasoning Ready, CSCI 111 with a grade of C or higher (may be taken concurrently), MATH 119 (or equivalent).  \nTypically Offered: Fall and spring\n  \nOffers an intensive introduction to discrete mathematics as used in computer science. Topics include sets, relations, propositional and predicate logic, basic proof methods including mathematical induction, digital logic circuits, complexity of algorithms, elementary combinatorics, and solving linear recurrence relations. 3 hours discussion.  (005550)\n  \nCross listing(s): CSCI 217  \nGrade Basis: Graded  \nRepeatability: You may take this course for a maximum of 3 units  \nCourse Attributes: Lower Division  ',
#   '{"name": "MATH 3A - Calculus I", "discipline": "Mathematics", "topics": ["Calculus", "Differential Equations"]}',
#   '```\n{\n  "name": "MATH 217 - Discrete Mathematics",\n  "discipline": "Mathematics",\n  "topics": ["Sets", "Relations", "Propositional and predicate logic", "Basic proof methods", "Mathematical induction", "Digital logic circuits", "Complexity of algorithms", "Elementary combinatorics", "Solving linear recurrence relations"]\n}\n```',
#   0),
#  ('MATH-1A 4 UNITS\nSingle Variable Calculus I - Early\nTranscendentals\nT R A N S E R A B L E T O C S U A N D U C - U C U N I T L I M I T\nC - I D : M AT H 2 1 0\n7 2 L E C T U R E H O U R S\nA first course in differential and integral calculus of a single variable:\nfunctions; limits and continuity; techniques and applications of\ndifferentiation and integration; Fundamental Theorem of Calculus.\nPrimarily for Science, Technology, Engineering and Math Majors.\nGrades are P/NP Option.\nPrerequisite(s): MATH-20; MATH-21; or satisfactory score on the\nmathematics placement test.',
#   'CS 12 Assembly Language Programming/Computer Architecture\n\n(Formerly CIS 22) 4 Units/4 hours lecture. Grade Only. Prerequisite: Course Completion of CS 10B.\nTransferability: CSU;UC.\nC-ID: COMP 142\nDescription: Introductory computer architecture and techniques of assembly language programming as they apply to modern microprocessors such as I-86, ARM and/or PowerPC. Topics include theory and concepts of virtual memory, pipelines, caches, and multitasking, hardware architecture (bus, memory, stack, I/O, interrupts), design of structured assembly language code, use of software interrupts, survey arithmetic notations (binary, hexadecimal, floating- point, binary-coded decimal), input/output, and disk processing concepts.',
#   '```\n{\n  "name": "MATH-1A",\n  "discipline": "Mathematics",\n  "topics": ["Calculus", "Differential Equations"]\n}\n```',
#   '```\n{\n  "name": "CS 12 Assembly Language Programming/Computer Architecture",\n  "discipline": "Computer Science",\n  "topics": [\n    "Assembly Language Programming",\n    "Computer Architecture",\n    "Virtual Memory",\n    "Pipelines",\n    "Caches",\n    "Multitasking",\n    "Hardware Architecture",\n    "Bus",\n    "Memory",\n    "Stack",\n    "I/O",\n    "Interrupts",\n    "Structured Assembly Language Code",\n    "Software Interrupts",\n    "Arithmetic Notation",\n    "Binary",\n    "Hexadecimal",\n    "Floating-Point",\n    "Binary-Coded Decimal",\n    "Input/Output",\n    "Disk Processing Concepts"\n  ]\n}\n```',
#   0),
#  ...]

# %%
for course in target_sample:
    df_eval = pd.concat([df_eval, pd.DataFrame(course, columns=['target_raw', 'source_raw', 'target_topics', 'source_topics', 'label'])])

# %%
df_eval = df_eval.reset_index().drop(columns=['index'])

# %%
df_eval
# Out:
#                                              target_raw  \
# 0     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 1     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 2     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 3     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 4     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# ...                                                 ...
# 8514  CS 51  (C-ID COMP 142)         3 units  \nIntr...
# 8515  CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# 8516  CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# 8517  COMSC-2 3 UNITS\nComputer Assembly Language\nT...
# 8518  Introduction to Assembly Language Programming\...
#
#                                              source_raw  \
# 0     MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# 1     MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# 2     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# 3     MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# 4     MATH 150 - Calculus I\n4 Units\nFour hours lec...
# ...                                                 ...
# 8514  CSCI 190  Discrete Mathematics Applied to Comp...
# 8515  COMP 256 - Discrete Structures for Computer Sc...
# 8516  MATH 170A - Mathematical Structures I\n3 Units...
# 8517  MATH 1410 - Calculus I\n4 Units\n\nInequalitie...
# 8518  MATH 1A - CALCULUS\n5 Units\n\nPrerequisite:  ...
#
#                                           target_topics  \
# 0     {"name": "MATH 226 - Calculus I", "discipline"...
# 1     {"name": "MATH 226 - Calculus I", "discipline"...
# 2     {"name": "MATH 226 - Calculus I", "discipline"...
# 3     {"name": "MATH 226 - Calculus I", "discipline"...
# 4     {"name": "MATH 226 - Calculus I", "discipline"...
# ...                                                 ...
# 8514  ```\n{\n  "name": "CS 51",\n  "discipline": "C...
# 8515  {"name": "CIS020", "discipline": "Computer Sci...
# 8516  {"name": "CIS020", "discipline": "Computer Sci...
# 8517  ```\n{\n  "name": "Computer Assembly Language"...
# 8518  ```\n{\n  "name": "Introduction to Assembly La...
#
#                                           source_topics  label
# 0     ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...      1
# 1     ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...      1
# 2     ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...      1
# 3     {"name": "MATH 141 - Calculus I", "discipline"...      1
# 4     ```\n{\n  "name": "MATH 150 - Calculus I",\n  ...      1
# ...                                                 ...    ...
# 8514  ```\n{\n  "name": "CSCI 190  Discrete Mathemat...      0
# 8515  ```\n{\n  "name": "COMP 256 - Discrete Structu...      0
# 8516  {"name": "MATH 170A - Mathematical Structures ...      0
# 8517  {"name": "MATH 1410 - Calculus I", "discipline...      0
# 8518  {"name": "MATH 1A - CALCULUS", "discipline": "...      0
#
# [8519 rows x 5 columns]

# %%
df_eval.iloc[-5:,0]
# Out:
# 8514    CS 51  (C-ID COMP 142)         3 units  \nIntr...
# 8515    CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# 8516    CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# 8517    COMSC-2 3 UNITS\nComputer Assembly Language\nT...
# 8518    Introduction to Assembly Language Programming\...
# Name: target_raw, dtype: object

# %%
df_eval.iloc[-5:,1]
# Out:
# 8514    CSCI 190  Discrete Mathematics Applied to Comp...
# 8515    COMP 256 - Discrete Structures for Computer Sc...
# 8516    MATH 170A - Mathematical Structures I\n3 Units...
# 8517    MATH 1410 - Calculus I\n4 Units\n\nInequalitie...
# 8518    MATH 1A - CALCULUS\n5 Units\n\nPrerequisite:  ...
# Name: source_raw, dtype: object

# %%
with open('../data/df_eval.pkl', 'wb') as f:
    dill.dump(df_eval, f)

# with open('../data/df_eval.pkl', 'rb') as f:
#     df_eval = dill.load(f)

# %% [markdown]
# # Baseline Equivalency
#
# Equivalency assessed from raw course description text

# %% [markdown]
# ## Single pair of courses assessment

# %%
# Prompt Template for Course Equivalency prediction

equiv_prompt_template = """
Determine whether the two \
following courses are equivalent. For course equivalency, respond with 'true' \
or 'false'.\n
{format_instructions}\n
Course 1:\n```{course1_desc}```\n
Course 2:\n```{course2_desc}```
"""

# %%
from typing import Literal

class Equivalency(BaseModel):
    # courses: list[str] = Field(description="subject of the two courses to be evaluated")
    isEquiv: bool = Field(description="equivalency prediction")

equiv_parser = PydanticOutputParser(pydantic_object=Equivalency)

equiv_prompt = PromptTemplate(
    template=equiv_prompt_template,
    input_variables=["course1_desc", "course2_desc"],
    partial_variables={"format_instructions": equiv_parser.get_format_instructions()}
)

# %%
df.iloc[0,0]
# Out:
# 'MATH 226 - Calculus I\n4 Units\n\nGraphs. Differentiation: theory, techniques, and applications. Integration: Fundamental Theorem of Calculus and applications. Transcendental functions.'

# %%
course1_desc = df.iloc[0,4]
course2_desc = df.iloc[2,4]
course3_desc = "\n".join(course2_desc.split("\n")[0:2]) + """\
\n\nSets, functions, relations, algorithms, induction, \
differentiation, integration, and transcentental functions."""
# + "\n\nSets, relations, induction, algorithms, differentiation, and limits."
print(course1_desc, "\n\n", course2_desc, "\n\n", course3_desc)
# Out:
# CSC 230 - Discrete Mathematical Structures for Computer Science
# 3 Units
#
# Review of set algebra, relations and functions, permutations, propositional logic, proof techniques, introduction to graph theory, and infinite sets, and their applications to computer science.
#
#  MATH 253 - Discrete Mathematics
# 3 Units, 3 Lecture Hours
# Prerequisites: MATH 101T (C), or MATH 102 and CS 111
#
# Sets, functions, relations, algorithms, induction, recursion, combinatorics, graphs, trees, and propositional logic.
#
#  MATH 253 - Discrete Mathematics
# 3 Units, 3 Lecture Hours
#
# Sets, functions, relations, algorithms, induction, differentiation, integration, and transcentental functions.

# %%
_input = equiv_prompt.format_prompt(course1_desc=course1_desc, course2_desc=course2_desc)
print(_input.to_string())
# Out:
# Determine whether the two following courses are equivalent. For course equivalency, respond with 'true' or 'false'.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"isEquiv": {"title": "Isequiv", "description": "equivalency prediction", "type": "boolean"}}, "required": ["isEquiv"]}
# ```
#
# Course 1:
# ```CSC 230 - Discrete Mathematical Structures for Computer Science
# 3 Units
#
# Review of set algebra, relations and functions, permutations, propositional logic, proof techniques, introduction to graph theory, and infinite sets, and their applications to computer science.```
#
# Course 2:
# ```MATH 253 - Discrete Mathematics
# 3 Units, 3 Lecture Hours
# Prerequisites: MATH 101T (C), or MATH 102 and CS 111
#
# Sets, functions, relations, algorithms, induction, recursion, combinatorics, graphs, trees, and propositional logic.```

# %%
equiv_output_palm = palm(_input.to_string())
equiv_output_palm
# Out:
# '{"isEquiv": true}'

# %%
equiv_data_palm = equiv_parser.parse(equiv_output_palm)
equiv_data_palm
# Out:
# Equivalency(isEquiv=True)

# %% [markdown]
# ## Pairwise Equivalency Assessment using Raw Text (FULL DATASET)

# %%
with open("../data/prediction_df.pkl", "rb") as f:
    df_eval = dill.load(f)

# %%
df2.head()
# Out:
#                                                                                           MATH226 eqv  \
# School
# SFSU                                                MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# Berkeley City College                               MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# California Polytechnic State University, Humboldt   MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# California Polytechnic State University, Pomona     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# California Polytechnic State University, San Lu...  MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
#
#                                                                                      MATH226 mult eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  MATH 142 - Calculus II\n4 units\nGE Area B1\nP...
#
#                                                                                       MATH226 alt eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 141 - Calculus I \n4 Units \nPrerequisite...
#
#                                                                                  MATH226 alt mult eqv  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  HNRS 142 - Calculus II \n4 units\nPrerequisite...
#
#                                                                                            CSC230 eqv  \
# School
# SFSU                                                CSC 230 - Discrete Mathematical Structures for...
# Berkeley City College                                  MATH 11 - Discrete Mathematics\n4 units\n\nN/A
# California Polytechnic State University, Humboldt   MATH 253 - Discrete Mathematics\n3 Units, 3 Le...
# California Polytechnic State University, Pomona     CS 1300 - Discrete Structures\n4 Units\nPrereq...
# California Polytechnic State University, San Lu...                                                NaN
#
#                                                    CSC230 alt eqv  \
# School
# SFSU                                                          NaN
# Berkeley City College                                         NaN
# California Polytechnic State University, Humboldt             NaN
# California Polytechnic State University, Pomona               NaN
# California Polytechnic State University, San Lu...            NaN
#
#                                                                                            CSC256 eqv  \
# School
# SFSU                                                CSC 256 - Machine Structures\n3 Units\n\nDigit...
# Berkeley City College                               CIS 20: Microcomputer Assembly Language\n4 Uni...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     CS 2640 - Computer Organization and Assembly P...
# California Polytechnic State University, San Lu...                                                NaN
#
#                                                    CSC256 multipleEqv  \
# School
# SFSU                                                              NaN
# Berkeley City College                                             NaN
# California Polytechnic State University, Humboldt                 NaN
# California Polytechnic State University, Pomona                   NaN
# California Polytechnic State University, San Lu...                NaN
#
#                                                                                      MATH226 eqv data  \
# School
# SFSU                                                {"name": "MATH 226 - Calculus I", "discipline"...
# Berkeley City College                               ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...
# California Polytechnic State University, San Lu...  {"name": "MATH 141 - Calculus I", "discipline"...
#
#                                                                                 MATH226 mult eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  ```\n{\n  "name": "MATH 142 - Calculus II",\n ...
#
#                                                                                  MATH226 alt eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  ```\n{\n  "name": "HNRS 141 - Calculus I",\n  ...
#
#                                                                             MATH226 alt mult eqv data  \
# School
# SFSU                                                                                              NaN
# Berkeley City College                                                                             NaN
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona                                                   NaN
# California Polytechnic State University, San Lu...  ```\n{\n  "name": "HNRS 142 - Calculus II",\n ...
#
#                                                                                       CSC230 eqv data  \
# School
# SFSU                                                {"name": "CSC 230 - Discrete Mathematical Stru...
# Berkeley City College                               {"name": "MATH 11 - Discrete Mathematics", "di...
# California Polytechnic State University, Humboldt   ```\n{\n  "name": "MATH 253 - Discrete Mathema...
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 1300 - Discrete Structur...
# California Polytechnic State University, San Lu...                                                NaN
#
#                                                    CSC230 alt eqv data  \
# School
# SFSU                                                               NaN
# Berkeley City College                                              NaN
# California Polytechnic State University, Humboldt                  NaN
# California Polytechnic State University, Pomona                    NaN
# California Polytechnic State University, San Lu...                 NaN
#
#                                                                                       CSC256 eqv data  \
# School
# SFSU                                                ```\n{\n  "name": "CSC 256 - Machine Structure...
# Berkeley City College                               ```\n{\n  "name": "CIS 20: Microcomputer Assem...
# California Polytechnic State University, Humboldt                                                 NaN
# California Polytechnic State University, Pomona     ```\n{\n  "name": "CS 2640 - Computer Organiza...
# California Polytechnic State University, San Lu...                                                NaN
#
#                                                    CSC256 multipleEqv data
# School
# SFSU                                                                   NaN
# Berkeley City College                                                  NaN
# California Polytechnic State University, Humboldt                      NaN
# California Polytechnic State University, Pomona                        NaN
# California Polytechnic State University, San Lu...                     NaN

# %%
short = 0
tot = 0
for e in df2["MATH226 eqv data"]:
    if type(e) != float:
        a = course_parser.parse(e).name
        tot += 1
        if len(a) < 10:
            print(a)
            short += 1
print(f"Total: {tot}")
print(f"Short: {short}")
# Out:
# MATH 60
# MATH 3A
# MATH-120
# MATH 071
# MATH 7
# MATH020
# MATH-1A
# Total: 62
# Short: 7

# %%
len(df_eval)
# Out:
# 8519

# %%
def isEquivRaw(target, source):
    _input = equiv_prompt.format_prompt(course1_desc=target, course2_desc=source)
    # print(_input.to_string())
    res = palm(_input.to_string())
    # print(f"Response: {res}")
    res = equiv_parser.parse(res)
    # print(f"Parsed Response: {res.isEquiv}")
    if res.isEquiv == True:
        return 1
    else:
        return 0

# %%
def process_raw(df_eval: pd.DataFrame, preds: list):
    import time
    if preds:
        start = len(preds)
    else:
        start = 0
    step = int(len(df_eval)/50)
    for i in tqdm(range(start,len(df_eval), step), desc="Total Progress", position=0):
        if i + step < len(df_eval):
            preds.extend(list(map(isEquivRaw, tqdm(df_eval.iloc[i:i+step,0], desc=f"Batch Progress: {int((i-start+step)/170)}", position=1, leave=True), df_eval.iloc[i:i+step,1])))
            # print(f"Saving Progress: {i+step}")
            with open(f"../data/chunks/raw_text/preds_raw_0-{i+step}.pkl", "wb") as f:
                dill.dump(preds, f)
            time.sleep(30)
        else:
            preds.extend(list(map(isEquivRaw, tqdm(df_eval.iloc[i:,0], desc=f"Batch Progress: {int((len(df_eval)-start)/170)+1}", position=1, leave=True), df_eval.iloc[i:,1])))
            with open(f"../data/chunks/raw_text/preds_raw_final.pkl", "wb") as f:
                dill.dump(preds, f)
            print("Finished")

# %%
df_eval.head()
# Out:
#                                           target_raw  \
# 0  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 1  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 2  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 3  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 4  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
#
#                                           source_raw  \
# 0  MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# 1  MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# 2  MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# 3  MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# 4  MATH 150 - Calculus I\n4 Units\nFour hours lec...
#
#                                        target_topics  \
# 0  {"name": "MATH 226 - Calculus I", "discipline"...
# 1  {"name": "MATH 226 - Calculus I", "discipline"...
# 2  {"name": "MATH 226 - Calculus I", "discipline"...
# 3  {"name": "MATH 226 - Calculus I", "discipline"...
# 4  {"name": "MATH 226 - Calculus I", "discipline"...
#
#                                        source_topics  label  preds_raw  \
# 0  ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...      1          1
# 1  ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...      1          1
# 2  ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...      1          1
# 3  {"name": "MATH 141 - Calculus I", "discipline"...      1          1
# 4  ```\n{\n  "name": "MATH 150 - Calculus I",\n  ...      1          1
#
#    pred_topics
# 0            0
# 1            1
# 2            0
# 3            1
# 4            1

# %%
len(preds_raw)
# Out:
# 7820

# %%
process_raw(df_eval, preds_raw)
df_eval["preds_raw"] = preds_raw
# Out:
# Total Progress:   0%|          | 0/5 [00:00<?, ?it/s]
# Batch Progress: 1:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 2:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 3:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 4:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 5:   0%|          | 0/19 [00:00<?, ?it/s]
# Finished

# %%
df_eval.loc[:,"label"].value_counts()
# Out:
# label
# 0    4260
# 1    4259
# Name: count, dtype: int64

# %%
df_eval.loc[:,"preds_raw"].value_counts()
# Out:
# preds_raw
# 0    7281
# 1    1238
# Name: count, dtype: int64

# %% [markdown]
# # Topic Equivalency

# %%
# Prompt Template for Course Equivalency prediction

topicequiv_prompt_template = """
Given the discipline and list of topics for the two courses below, determine whether the two \
are equivalent. For course equivalency, respond with 'true' or 'false'.\n
{format_instructions}\n
Course 1 Discipline: ```{course1_disc}```\nCourse 1 Topics: ```{course1_topics}```\n
Course 2 Discipline: ```{course2_disc}```\nCourse 2 Topics: ```{course2_topics}``````
"""

# %%
class TopicEquivalency(BaseModel):
    isEquiv: bool = Field(description="equivalency prediction")

topicequiv_parser = PydanticOutputParser(pydantic_object=TopicEquivalency)

topicequiv_prompt = PromptTemplate(
    template=topicequiv_prompt_template,
    input_variables=["course1_disc", "course1_topics", "course2_disc", "course2_topics"],
    partial_variables={"format_instructions": topicequiv_parser.get_format_instructions()}
)

# %%
df2.iloc[0,8]
# Out:
# '{"name": "MATH 226 - Calculus I", "discipline": "Mathematics", "topics": ["Calculus", "Differentiation", "Integration", "Transcendental functions"]}'

# %%
course1_data = course_parser.parse(df2.iloc[0,8])
course2_data = course_parser.parse(df2.iloc[2,8])
course3_data = course_parser.parse(df2.iloc[0,8])
course3_data.topics = [ "Sets", "functions", "relations", "algorithms", "induction",
                        "differentiation", "integration", "transcentental", "functions" ]
print(", ".join(course1_data.topics), "\n\n", ", ".join(course2_data.topics), "\n\n", ", ".join(course3_data.topics))
# Out:
# Calculus, Differentiation, Integration, Transcendental functions
#
#  Limits, Continuity, Derivatives, Integrals
#
#  Sets, functions, relations, algorithms, induction, differentiation, integration, transcentental, functions

# %%
_input = topicequiv_prompt.format_prompt(
    course1_disc=course1_data.discipline, 
    course1_topics=course1_data.topics,
    course2_disc=course3_data.discipline, 
    course2_topics=course3_data.topics
)
print(_input.to_string())
# Out:
# Given the discipline and list of topics for the two courses below, determine whether the two are equivalent. For course equivalency, respond with 'true' or 'false'.
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"isEquiv": {"title": "Isequiv", "description": "equivalency prediction", "type": "boolean"}}, "required": ["isEquiv"]}
# ```
#
# Course 1 Discipline: ```Mathematics```
# Course 1 Topics: ```['Calculus', 'Differentiation', 'Integration', 'Transcendental functions']```
#
# Course 2 Discipline: ```Mathematics```
# Course 2 Topics: ```['Sets', 'functions', 'relations', 'algorithms', 'induction', 'differentiation', 'integration', 'transcentental', 'functions']``````

# %%
topicequiv_output_palm = palm(_input.to_string())
topicequiv_output_palm
# Out:
# '{"isEquiv": false}'

# %%
topicequiv_data_palm = topicequiv_parser.parse(topicequiv_output_palm)
topicequiv_data_palm
# Out:
# TopicEquivalency(isEquiv=False)

# %% [markdown]
# ## Pairwise Equivalency Assessment using Topics and Discipline (FULL DATASET)

# %%
def isEquivTopics(target, source):
    target = course_parser.parse(target)
    source = course_parser.parse(source)
    _input = topicequiv_prompt.format_prompt(
        course1_disc=target.discipline, 
        course1_topics=target.topics,
        course2_disc=source.discipline, 
        course2_topics=source.topics
    )
    # print(_input.to_string())
    res = palm(_input.to_string())
    # print(f"Response: {res}")
    res = topicequiv_parser.parse(res)
    # print(f"Parsed Response: {res.isEquiv}")
    if res.isEquiv == True:
        return 1
    else:
        return 0

# %%
df_eval.iloc[10,0]
# Out:
# '{"name": "MATH 226 - Calculus I", "discipline": "Mathematics", "topics": ["Calculus", "Differentiation", "Integration", "Transcendental functions"]}'

# %%
df_eval.iloc[10,1]
# Out:
# '{"name": "MATH 130 - Calculus I", "discipline": "Mathematics", "topics": ["Calculus", "Limits", "Derivatives", "Optimization", "Antiderivatives", "Integration", "Fundamental Theorem of Calculus"]}'

# %%
df_eval.iloc[10,2]
# Out:
# 1

# %%
isEquivTopics(df_eval.iloc[10,0], df_eval.iloc[10,1])
# Out:
# 1

# %%
import time

def process_topics(df_eval: pd.DataFrame, preds: list):
    if preds:
        start = len(preds)
    else:
        start = 0
    step = int(len(df_eval)/50)
    for i in tqdm(range(start,len(df_eval), step), desc="Total Progress", position=0):
        if i + step < len(df_eval):
            preds.extend(list(map(isEquivTopics, tqdm(df_eval.iloc[i:i+step,2], desc=f"Batch Progress: {int((i-start+step)/170)}", position=1, leave=True), df_eval.iloc[i:i+step,3])))
            # print(f"Saving Progress: {i+step}")
            with open(f"../data/chunks/topics/topic_preds_0-{i+step}.pkl", "wb") as f:
                dill.dump(preds, f)
            time.sleep(30)
        else:
            preds.extend(list(map(isEquivTopics, tqdm(df_eval.iloc[i:,2], desc=f"Batch Progress: {int((len(df_eval)-start)/170)+1}", position=1, leave=True), df_eval.iloc[i:,3])))
            with open(f"../data/chunks/topics/topic_preds_final.pkl", "wb") as f:
                dill.dump(preds, f)
            print("Finished")

# %%
df_eval.head()
# Out:
#                                           target_raw  \
# 0  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 1  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 2  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 3  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 4  MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
#
#                                           source_raw  \
# 0  MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# 1  MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# 2  MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# 3  MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# 4  MATH 150 - Calculus I\n4 Units\nFour hours lec...
#
#                                        target_topics  \
# 0  {"name": "MATH 226 - Calculus I", "discipline"...
# 1  {"name": "MATH 226 - Calculus I", "discipline"...
# 2  {"name": "MATH 226 - Calculus I", "discipline"...
# 3  {"name": "MATH 226 - Calculus I", "discipline"...
# 4  {"name": "MATH 226 - Calculus I", "discipline"...
#
#                                        source_topics  label  preds_raw  \
# 0  ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...      1          1
# 1  ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...      1          1
# 2  ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...      1          1
# 3  {"name": "MATH 141 - Calculus I", "discipline"...      1          1
# 4  ```\n{\n  "name": "MATH 150 - Calculus I",\n  ...      1          1
#
#    pred_topics
# 0            0
# 1            1
# 2            0
# 3            1
# 4            1

# %%
# preds_topics = []
process_topics (df_eval, preds_topics)
df_eval["pred_topics"] = preds_topics
# Out:
# Total Progress:   0%|          | 0/49 [00:00<?, ?it/s]
# Batch Progress: 1:   0%|          | 0/170 [00:00<?, ?it/s]
# Retrying langchain.llms.google_palm.generate_with_retry.<locals>._generate_with_retry in 2.0 seconds as it raised ServiceUnavailable: 503 The service is currently unavailable..
# Retrying langchain.llms.google_palm.generate_with_retry.<locals>._generate_with_retry in 2.0 seconds as it raised ServiceUnavailable: 503 The service is currently unavailable..
# Retrying langchain.llms.google_palm.generate_with_retry.<locals>._generate_with_retry in 2.0 seconds as it raised ServiceUnavailable: 503 The service is currently unavailable..
# Batch Progress: 2:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 3:   0%|          | 0/170 [00:00<?, ?it/s]
# Retrying langchain.llms.google_palm.generate_with_retry.<locals>._generate_with_retry in 2.0 seconds as it raised ServiceUnavailable: 503 The service is currently unavailable..
# Batch Progress: 4:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 5:   0%|          | 0/170 [00:00<?, ?it/s]
# Retrying langchain.llms.google_palm.generate_with_retry.<locals>._generate_with_retry in 2.0 seconds as it raised ServiceUnavailable: 503 The service is currently unavailable..
# Batch Progress: 6:   0%|          | 0/170 [00:00<?, ?it/s]
# Retrying langchain.llms.google_palm.generate_with_retry.<locals>._generate_with_retry in 2.0 seconds as it raised ServiceUnavailable: 503 The service is currently unavailable..
# Retrying langchain.llms.google_palm.generate_with_retry.<locals>._generate_with_retry in 2.0 seconds as it raised ServiceUnavailable: 503 The service is currently unavailable..
# Batch Progress: 7:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 8:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 9:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 10:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 11:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 12:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 13:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 14:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 15:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 16:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 17:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 18:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 19:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 20:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 21:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 22:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 23:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 24:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 25:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 26:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 27:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 28:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 29:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 30:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 31:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 32:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 33:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 34:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 35:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 36:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 37:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 38:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 39:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 40:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 41:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 42:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 43:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 44:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 45:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 46:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 47:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 48:   0%|          | 0/170 [00:00<?, ?it/s]
# Batch Progress: 49:   0%|          | 0/19 [00:00<?, ?it/s]
# Finished

# %%
df_eval.loc[:,"label"].value_counts()
# Out:
# label
# 0    4260
# 1    4259
# Name: count, dtype: int64

# %%
df_eval.loc[:,"pred_topics"].value_counts()
# Out:
# pred_topics
# 0    7178
# 1    1341
# Name: count, dtype: int64

# %%
df_eval
# Out:
#                                              target_raw  \
# 0     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 1     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 2     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 3     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# 4     MATH 226 - Calculus I\n4 Units\n\nGraphs. Diff...
# ...                                                 ...
# 8514  CS 51  (C-ID COMP 142)         3 units  \nIntr...
# 8515  CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# 8516  CIS020:\n\n3.0 Units\nPrint\nDescription:\n\nA...
# 8517  COMSC-2 3 UNITS\nComputer Assembly Language\nT...
# 8518  Introduction to Assembly Language Programming\...
#
#                                              source_raw  \
# 0     MATH 3A - Calculus I\n5 Units, 5 lecture hours...
# 1     MATH 109 - Calculus I\n4 Units, 4 Lecture hour...
# 2     MAT 1140 - Calculus I\n4 Units\nPrerequisites:...
# 3     MATH 141 - Calculus I\n4 Units\nGE Area B1\nPr...
# 4     MATH 150 - Calculus I\n4 Units\nFour hours lec...
# ...                                                 ...
# 8514  CSCI 190  Discrete Mathematics Applied to Comp...
# 8515  COMP 256 - Discrete Structures for Computer Sc...
# 8516  MATH 170A - Mathematical Structures I\n3 Units...
# 8517  MATH 1410 - Calculus I\n4 Units\n\nInequalitie...
# 8518  MATH 1A - CALCULUS\n5 Units\n\nPrerequisite:  ...
#
#                                           target_topics  \
# 0     {"name": "MATH 226 - Calculus I", "discipline"...
# 1     {"name": "MATH 226 - Calculus I", "discipline"...
# 2     {"name": "MATH 226 - Calculus I", "discipline"...
# 3     {"name": "MATH 226 - Calculus I", "discipline"...
# 4     {"name": "MATH 226 - Calculus I", "discipline"...
# ...                                                 ...
# 8514  ```\n{\n  "name": "CS 51",\n  "discipline": "C...
# 8515  {"name": "CIS020", "discipline": "Computer Sci...
# 8516  {"name": "CIS020", "discipline": "Computer Sci...
# 8517  ```\n{\n  "name": "Computer Assembly Language"...
# 8518  ```\n{\n  "name": "Introduction to Assembly La...
#
#                                           source_topics  label  preds_raw  \
# 0     ```\n{\n  "name": "MATH 3A - Calculus I",\n  "...      1          1
# 1     ```\n{\n  "name": "MATH 109 - Calculus I",\n  ...      1          1
# 2     ```\n{\n  "name": "MAT 1140 - Calculus I",\n  ...      1          1
# 3     {"name": "MATH 141 - Calculus I", "discipline"...      1          1
# 4     ```\n{\n  "name": "MATH 150 - Calculus I",\n  ...      1          1
# ...                                                 ...    ...        ...
# 8514  ```\n{\n  "name": "CSCI 190  Discrete Mathemat...      0          0
# 8515  ```\n{\n  "name": "COMP 256 - Discrete Structu...      0          0
# 8516  {"name": "MATH 170A - Mathematical Structures ...      0          0
# 8517  {"name": "MATH 1410 - Calculus I", "discipline...      0          0
# 8518  {"name": "MATH 1A - CALCULUS", "discipline": "...      0          0
#
#       pred_topics
# 0               0
# 1               1
# 2               0
# 3               1
# 4               1
# ...           ...
# 8514            0
# 8515            0
# 8516            0
# 8517            0
# 8518            0
#
# [8519 rows x 7 columns]

# %%
with open("../data/prediction_df.pkl", "wb") as f:
    dill.dump(df_eval, f)

# %% [markdown]
# # Evaluation of Equivalency Predictions

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Raw Text Evaluation

# %%
print("Classification Report for Raw Text Evaluation")
print(classification_report(df_eval.iloc[:, 4], df_eval.iloc[:, 5],digits=4))
# Out:
# Classification Report for Raw Text Evaluation
#               precision    recall  f1-score   support
#
#            0     0.5825    0.9955    0.7349      4260
#            1     0.9847    0.2862    0.4435      4259
#
#     accuracy                         0.6409      8519
#    macro avg     0.7836    0.6409    0.5892      8519
# weighted avg     0.7835    0.6409    0.5892      8519

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(df_eval["label"], df_eval["preds_raw"]))
disp.plot()
disp.ax_.set_title("Raw Text Evaluation Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Raw Text Evaluation Confusion Matrix')

# %% [markdown]
# ## Discipline & Topic Evaluation

# %%
print("Classification Report for Discipline and Topic Evaluation")
print(classification_report(df_eval.iloc[:, 4], df_eval.iloc[:, 6],digits=4))
# Out:
# Classification Report for Discipline and Topic Evaluation
#               precision    recall  f1-score   support
#
#            0     0.5935    1.0000    0.7449      4260
#            1     1.0000    0.3149    0.4789      4259
#
#     accuracy                         0.6575      8519
#    macro avg     0.7967    0.6574    0.6119      8519
# weighted avg     0.7967    0.6575    0.6119      8519

# %%
disp2 = ConfusionMatrixDisplay(confusion_matrix(df_eval["label"], df_eval["pred_topics"]))
disp2.plot()
disp2.ax_.set_title("Discipline/Topic Evaluation Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Discipline/Topic Evaluation Confusion Matrix')

# %% [markdown]
# # DEPRECATED PROCESSES

# %% [markdown]
# #### Section: [Process Entire Dataframe](#process-entire-dataframe)
#
# I was going to convert the dataframe into a Python dictionary to process the
# data before realizing that I can just process the data directly from the dataframe.

# %%
# school_courses_desc_dict = df.to_dict(orient='index')
# school_courses_desc_dict = {school:{course:(desc if type(desc) is str else None) for course,desc in courses.items()} for school,courses in school_courses_desc_dict.items()}

# %%
# school_courses_desc_dict['SFSU']
